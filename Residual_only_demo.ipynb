# %%
from src.layers.Models import TinyDiffusion 

from torch.utils.data import DataLoader
from src.data.BaseData import DataSetTinyDiffusion
from src.utils.manage_device import select_device
# Out:
# /Data/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
cfg ={'device': 'cuda', 
      'model_type': {'model_name': 'Residual_only'}, 
      'model': {'depth': 3, 'size': 250, 'hidden_dim': 750, 'output_dim': 2, 'pos_emb': 'sinusoidal', 'input_size': 2}, 
      'trainer': {'num_epoch': 50, 'batch_size': 64, 'gradient_clip_threshhold': 1, 'eval_frequency': 10, 'sample_size': 2000}, 
      'dataset': {'number_data_points': 10000, 'joined': 0, 'name_dataset': [['dino', ''], ['mnist', 'density_map_0.pt']]}, 
      'optimizer': {'lr': 0.001, 'weight_decay': 0}, 
      'Diffusion': {'num_timesteps': 250, 'beta_start': 0.0001, 'beta_end': 0.02, 'beta_schedule': 'quadratic'}}

# %%
model_name = cfg["model_type"]["model_name"]
device = select_device(cfg['device'])
    # Correct way to merge dictionaries and add a new key in Python
model_config = {**cfg["model"], "device": device}
dataset_config = {**cfg["dataset"], "device": device}
dataset_config["name_dataset"] = [("dino", "") , ("moons", "")]
trainer_config = {
    **cfg["trainer"],
    "data_name": dataset_config["name_dataset"],
    "device": device,
}
optimizer_config = {**cfg["optimizer"]}
diff_config = {**cfg["Diffusion"], "device": device}

# %%
tinyDiff_builder = TinyDiffusion(
    model_name, model_config, trainer_config, optimizer_config, diff_config, device
)
print(tinyDiff_builder)
dataset = DataSetTinyDiffusion(**dataset_config)
print(dataset)
train_loader = DataLoader(
    dataset, batch_size=int(trainer_config["batch_size"]), shuffle=True
)
print(train_loader)
tinyDiff_builder.train(train_loader)
# Out:
# <src.layers.Models.TinyDiffusion object at 0x7f0eb0b62a10>
# [<torch.utils.data.dataset.TensorDataset object at 0x7f0e6117c990>, <torch.utils.data.dataset.TensorDataset object at 0x7f0e612c7810>]
# <src.data.BaseData.DataSetTinyDiffusion object at 0x7f0ea7dbfe50>
# <torch.utils.data.dataloader.DataLoader object at 0x7f0e7c1a2ed0>
# Epoch 1/50:   0%|          | 0/313 [00:00<?, ?it/s]/Data/saadelhfr/MAP583/Project_tiny_diffusion/src/Trainers/Residual_only_trainer.py:56: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   torch.nn.utils.clip_grad_norm(
# Epoch 1/50: 100%|██████████| 313/313 [00:00<00:00, 346.28it/s]
# The loss for epoch 1 is 4.189030327834189
# 100%|██████████| 250/250 [00:00<00:00, 669.92it/s]
# Epoch 2/50: 100%|██████████| 313/313 [00:00<00:00, 388.82it/s]
# The loss for epoch 2 is 3.8141527324914932
# Epoch 3/50: 100%|██████████| 313/313 [00:00<00:00, 392.55it/s]
# The loss for epoch 3 is 3.6919592479243875
# Epoch 4/50: 100%|██████████| 313/313 [00:00<00:00, 401.69it/s]
# The loss for epoch 4 is 3.7254155026748776
# Epoch 5/50: 100%|██████████| 313/313 [00:00<00:00, 391.60it/s]
# The loss for epoch 5 is 3.643802845850587
# Epoch 6/50: 100%|██████████| 313/313 [00:00<00:00, 391.19it/s]
# The loss for epoch 6 is 3.619684019125998
# Epoch 7/50: 100%|██████████| 313/313 [00:00<00:00, 407.59it/s]
# The loss for epoch 7 is 3.63047029171139
# Epoch 8/50: 100%|██████████| 313/313 [00:00<00:00, 423.10it/s]
# The loss for epoch 8 is 3.6588318636640906
# Epoch 9/50: 100%|██████████| 313/313 [00:00<00:00, 406.29it/s]
# The loss for epoch 9 is 3.577200039755553
# Epoch 10/50: 100%|██████████| 313/313 [00:00<00:00, 412.38it/s]
# The loss for epoch 10 is 3.6144365249201655
# Epoch 11/50: 100%|██████████| 313/313 [00:00<00:00, 420.30it/s]
# The loss for epoch 11 is 3.6346308467909694
# 100%|██████████| 250/250 [00:00<00:00, 682.15it/s]
# Epoch 12/50: 100%|██████████| 313/313 [00:00<00:00, 424.27it/s]
# The loss for epoch 12 is 3.5530620692297816
# Epoch 13/50: 100%|██████████| 313/313 [00:00<00:00, 425.68it/s]
# The loss for epoch 13 is 3.606492707040161
# Epoch 14/50: 100%|██████████| 313/313 [00:00<00:00, 423.81it/s]
# The loss for epoch 14 is 3.6045833858661354
# Epoch 15/50: 100%|██████████| 313/313 [00:00<00:00, 423.94it/s]
# The loss for epoch 15 is 3.5841755336150527
# Epoch 16/50: 100%|██████████| 313/313 [00:00<00:00, 424.37it/s]
# The loss for epoch 16 is 3.5671357437968254
# Epoch 17/50: 100%|██████████| 313/313 [00:00<00:00, 427.25it/s]
# The loss for epoch 17 is 3.589186241850257
# Epoch 18/50: 100%|██████████| 313/313 [00:00<00:00, 422.97it/s]
# The loss for epoch 18 is 3.5859092785976827
# Epoch 19/50: 100%|██████████| 313/313 [00:00<00:00, 399.60it/s]
# The loss for epoch 19 is 3.5484958956949413
# Epoch 20/50: 100%|██████████| 313/313 [00:00<00:00, 381.63it/s]
# The loss for epoch 20 is 3.6040873331949115
# Epoch 21/50: 100%|██████████| 313/313 [00:00<00:00, 398.05it/s]
# The loss for epoch 21 is 3.579564058687538
# 100%|██████████| 250/250 [00:00<00:00, 672.51it/s]
# Epoch 22/50: 100%|██████████| 313/313 [00:00<00:00, 400.05it/s]
# The loss for epoch 22 is 3.5803437186405063
# Epoch 23/50: 100%|██████████| 313/313 [00:00<00:00, 401.00it/s]
# The loss for epoch 23 is 3.5728111527860165
# Epoch 24/50: 100%|██████████| 313/313 [00:00<00:00, 396.64it/s]
# The loss for epoch 24 is 3.6065147258341312
# Epoch 25/50: 100%|██████████| 313/313 [00:00<00:00, 399.88it/s]
# The loss for epoch 25 is 3.5958400750532746
# Epoch 26/50: 100%|██████████| 313/313 [00:00<00:00, 385.11it/s]
# The loss for epoch 26 is 3.525375339202583
# Epoch 27/50: 100%|██████████| 313/313 [00:00<00:00, 398.66it/s]
# The loss for epoch 27 is 3.557747449260205
# Epoch 28/50: 100%|██████████| 313/313 [00:00<00:00, 398.95it/s]
# The loss for epoch 28 is 3.5450443467125297
# Epoch 29/50: 100%|██████████| 313/313 [00:00<00:00, 390.95it/s]
# The loss for epoch 29 is 3.5172514216974378
# Epoch 30/50: 100%|██████████| 313/313 [00:00<00:00, 394.26it/s]
# The loss for epoch 30 is 3.4893190707080066
# Epoch 31/50: 100%|██████████| 313/313 [00:00<00:00, 398.71it/s]
# The loss for epoch 31 is 3.581291828304529
# 100%|██████████| 250/250 [00:00<00:00, 672.41it/s]
# Epoch 32/50: 100%|██████████| 313/313 [00:00<00:00, 400.06it/s]
# The loss for epoch 32 is 3.5337929972447455
# Epoch 33/50: 100%|██████████| 313/313 [00:00<00:00, 399.48it/s]
# The loss for epoch 33 is 3.496637909207493
# Epoch 34/50: 100%|██████████| 313/313 [00:00<00:00, 398.94it/s]
# The loss for epoch 34 is 3.51806682953611
# Epoch 35/50: 100%|██████████| 313/313 [00:00<00:00, 398.96it/s]
# The loss for epoch 35 is 3.543948248028755
# Epoch 36/50: 100%|██████████| 313/313 [00:00<00:00, 394.74it/s]
# The loss for epoch 36 is 3.44622897868976
# Epoch 37/50: 100%|██████████| 313/313 [00:00<00:00, 394.35it/s]
# The loss for epoch 37 is 3.5493662916123867
# Epoch 38/50: 100%|██████████| 313/313 [00:00<00:00, 396.46it/s]
# The loss for epoch 38 is 3.5092809074558318
# Epoch 39/50: 100%|██████████| 313/313 [00:00<00:00, 397.38it/s]
# The loss for epoch 39 is 3.4783077454194427
# Epoch 40/50: 100%|██████████| 313/313 [00:00<00:00, 397.37it/s]
# The loss for epoch 40 is 3.487596600782126
# Epoch 41/50: 100%|██████████| 313/313 [00:00<00:00, 398.45it/s]
# The loss for epoch 41 is 3.474267054349184
# 100%|██████████| 250/250 [00:00<00:00, 672.01it/s]
# Epoch 42/50: 100%|██████████| 313/313 [00:00<00:00, 399.62it/s]
# The loss for epoch 42 is 3.487914863973856
# Epoch 43/50: 100%|██████████| 313/313 [00:00<00:00, 399.16it/s]
# The loss for epoch 43 is 3.476643132045865
# Epoch 44/50: 100%|██████████| 313/313 [00:00<00:00, 397.70it/s]
# The loss for epoch 44 is 3.461091852746904
# Epoch 45/50: 100%|██████████| 313/313 [00:00<00:00, 389.98it/s]
# The loss for epoch 45 is 3.504601836204529
# Epoch 46/50: 100%|██████████| 313/313 [00:00<00:00, 397.78it/s]
# The loss for epoch 46 is 3.533320100978017
# Epoch 47/50: 100%|██████████| 313/313 [00:00<00:00, 398.14it/s]
# The loss for epoch 47 is 3.4811282781884074
# Epoch 48/50: 100%|██████████| 313/313 [00:00<00:00, 386.96it/s]
# The loss for epoch 48 is 3.4285534196533263
# Epoch 49/50: 100%|██████████| 313/313 [00:00<00:00, 396.31it/s]
# The loss for epoch 49 is 3.5054861600510776
# Epoch 50/50: 100%|██████████| 313/313 [00:00<00:00, 394.99it/s]
# The loss for epoch 50 is 3.4893625201657414
# 100%|██████████| 250/250 [00:00<00:00, 669.29it/s]
# Training Report :
# +--------------------------+-------------------------------+
# | Key                      | Value                         |
# +==========================+===============================+
# | num_epoch                | 50                            |
# +--------------------------+-------------------------------+
# | batch_size               | 64                            |
# +--------------------------+-------------------------------+
# | gradient_clip_threshhold | 1                             |
# +--------------------------+-------------------------------+
# | eval_frequency           | 10                            |
# +--------------------------+-------------------------------+
# | sample_size              | 2000                          |
# +--------------------------+-------------------------------+
# | data_name                | [('dino', ''), ('moons', '')] |
# +--------------------------+-------------------------------+
# | device                   | cuda                          |
# +--------------------------+-------------------------------+
# | best loss achieved       | 3.4285534196533263            |
# +--------------------------+-------------------------------+

# %%
import torch
import os 

path_to_best_model = tinyDiff_builder.trainer.checkpoints_dir_path.split('Project_tiny_diffusion/')[-1]
path_to_best_model_model = os.path.join(path_to_best_model , 'Residual_only_best_loss.pth')
tinyDiff_builder.model.load_state_dict(torch.load(path_to_best_model_model))
# Out:
# <All keys matched successfully>

# %%
pah = tinyDiff_builder.trainer.model_save_path
print(pah)
# Out:
# /Data/saadelhfr/MAP583/Project_tiny_diffusion/Outputs/Residual_only_date_2024-03-15_01_0f5efe

# %%
import os 
import numpy as np
framse_path = os.path.join(pah, "frames")
framse_np = np.load(
"Outputs/Residual_only_date_2024-03-15_01_0f5efe/framse.npy"
)

# %%
import matplotlib.pyplot as plt

for i in range(framse_np.shape[0]):
    plt.scatter(framse_np[i][:, 0], framse_np[i][:, 1] , s = 5)
    plt.show()

# %%
dataset_config2 = dataset_config
dataset_config2["name_dataset"] = [("mnist", "Data/Densities/density_map_2.pt")]
dataset2 = DataSetTinyDiffusion(**dataset_config2)
train_loader2 = DataLoader(dataset2, batch_size=int(trainer_config["batch_size"]), shuffle=True)
# Out:
# [<torch.utils.data.dataset.TensorDataset object at 0x7feeb8c94d90>]

# %%
fig, axs = plt.subplots(2, 5, figsize=(20, 10))

for i in range(10):
    sample_np = tinyDiff_builder.trainer.sample(3000)
    sample_np = sample_np.cpu().detach().numpy()
    ax = axs[i // 5, i % 5]
    ax.scatter(sample_np[:, 0], sample_np[:, 1], s=5)
    ax.set_title(f'shuffled dataset Plot {i+1}')

plt.tight_layout()
plt.show()
# Out:
# 100%|██████████| 250/250 [00:00<00:00, 513.97it/s]
# 100%|██████████| 250/250 [00:00<00:00, 528.12it/s]
# 100%|██████████| 250/250 [00:00<00:00, 527.06it/s]
# 100%|██████████| 250/250 [00:00<00:00, 526.16it/s]
# 100%|██████████| 250/250 [00:00<00:00, 521.82it/s]
# 100%|██████████| 250/250 [00:00<00:00, 527.20it/s]
# 100%|██████████| 250/250 [00:00<00:00, 528.77it/s]
# 100%|██████████| 250/250 [00:00<00:00, 527.78it/s]
# 100%|██████████| 250/250 [00:00<00:00, 530.39it/s]
# 100%|██████████| 250/250 [00:00<00:00, 531.16it/s]

# %%
print(sample_np.shape)
# Out:
# (3000, 2)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import expit

def create_intensity_grid(points):
    # Get the minimum and maximum values for each dimension
    min_x, min_y = np.min(points, axis=0)
    max_x, max_y = np.max(points, axis=0)

    # Create a grid of size 28x28
    grid_x, grid_y = np.meshgrid(np.linspace(min_x, max_x, 28), np.linspace(min_y, max_y, 28))

    # Initialize the intensity grid
    intensity_grid = np.zeros_like(grid_x)

    # Iterate over each pixel in the grid
    for i in range(27):
        for j in range(27):
            # Get the boundaries of the current pixel
            x_min, x_max = grid_x[i, j], grid_x[i, j+1]
            y_min, y_max = grid_y[i, j], grid_y[i+1, j]

            # Count the number of points falling within the current pixel
            num_points = np.sum((points[:, 0] >= x_min) & (points[:, 0] < x_max) & (points[:, 1] >= y_min) & (points[:, 1] < y_max))

            # Calculate the intensity as the sigmoid of the number of points

            # Set the intensity of the current pixel in the grid
            intensity_grid[i, j] = num_points

    return intensity_grid

# Example usage
points = sample_np  # Replace with your numpy array of shape (nbr_points, 2)
intensity_grid = create_intensity_grid(points)

# Plot the intensity grid
plt.imshow(intensity_grid, cmap='gray')
plt.show()

# %%
import matplotlib.pyplot as plt

for i in range(framse_np.shape[0]):
    plt.scatter(framse_np[i][:, 0], framse_np[i][:, 1] , s = 5)
    plt.show()

# %%
print(tinyDiff_builder.model)
# Out:
# MLP(
#   (time_embedding): Positional_embedding(
#     (embedding): Sinusoidal_embedding_trans()
#   )
#   (positional_embeder_1): Positional_embedding(
#     (embedding): Sinusoidal_embedding_trans()
#   )
#   (positional_embeder_2): Positional_embedding(
#     (embedding): Sinusoidal_embedding_trans()
#   )
#   (MLP): Sequential(
#     (0): Linear(in_features=384, out_features=128, bias=True)
#     (1): GELU(approximate='none')
#     (block_0): Block(
#       (linear_layer): Linear(in_features=128, out_features=128, bias=True)
#       (activate): GELU(approximate='none')
#     )
#     (block_1): Block(
#       (linear_layer): Linear(in_features=128, out_features=128, bias=True)
#       (activate): GELU(approximate='none')
#     )
#     (block_2): Block(
#       (linear_layer): Linear(in_features=128, out_features=128, bias=True)
#       (activate): GELU(approximate='none')
#     )
#     (block_3): Block(
#       (linear_layer): Linear(in_features=128, out_features=128, bias=True)
#       (activate): GELU(approximate='none')
#     )
#     (final_layer): Linear(in_features=128, out_features=2, bias=True)
#   )
# )

# %%
tinyDiff_builder.train(train_loader2)
# Out:
# Epoch 1/50:   0%|          | 0/157 [00:00<?, ?it/s]/Data/saadelhfr/MAP583/Project_tiny_diffusion/src/Trainers/Residual_only_trainer.py:56: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   torch.nn.utils.clip_grad_norm(
# Epoch 1/50: 100%|██████████| 157/157 [00:00<00:00, 358.99it/s]
# The loss for epoch 1 is 0.3332338438485749
# 100%|██████████| 250/250 [00:00<00:00, 916.61it/s]
# Epoch 2/50: 100%|██████████| 157/157 [00:00<00:00, 394.05it/s]
# The loss for epoch 2 is 0.3251390131772496
# Epoch 3/50: 100%|██████████| 157/157 [00:00<00:00, 398.69it/s]
# The loss for epoch 3 is 0.3404514889116399
# Epoch 4/50: 100%|██████████| 157/157 [00:00<00:00, 397.76it/s]
# The loss for epoch 4 is 0.3155331847956404
# Epoch 5/50: 100%|██████████| 157/157 [00:00<00:00, 399.14it/s]
# The loss for epoch 5 is 0.32258357328828424
# Epoch 6/50: 100%|██████████| 157/157 [00:00<00:00, 401.35it/s]
# The loss for epoch 6 is 0.32805583998560905
# Epoch 7/50: 100%|██████████| 157/157 [00:00<00:00, 399.10it/s]
# The loss for epoch 7 is 0.30413442122517154
# Epoch 8/50: 100%|██████████| 157/157 [00:00<00:00, 399.89it/s]
# The loss for epoch 8 is 0.3299647126113996
# Epoch 9/50: 100%|██████████| 157/157 [00:00<00:00, 400.82it/s]
# The loss for epoch 9 is 0.3249163604923524
# Epoch 10/50: 100%|██████████| 157/157 [00:00<00:00, 400.54it/s]
# The loss for epoch 10 is 0.3216875034850091
# Epoch 11/50: 100%|██████████| 157/157 [00:00<00:00, 401.84it/s]
# The loss for epoch 11 is 0.3402961558313109
# 100%|██████████| 250/250 [00:00<00:00, 937.71it/s]
# Epoch 12/50: 100%|██████████| 157/157 [00:00<00:00, 402.73it/s]
# The loss for epoch 12 is 0.3223364904988557
# Epoch 13/50: 100%|██████████| 157/157 [00:00<00:00, 401.52it/s]
# The loss for epoch 13 is 0.30960101960226893
# Epoch 14/50: 100%|██████████| 157/157 [00:00<00:00, 399.89it/s]
# The loss for epoch 14 is 0.3293970520608127
# Epoch 15/50: 100%|██████████| 157/157 [00:00<00:00, 401.00it/s]
# The loss for epoch 15 is 0.31699530957848765
# Epoch 16/50: 100%|██████████| 157/157 [00:00<00:00, 402.61it/s]
# The loss for epoch 16 is 0.31924136471934617
# Epoch 17/50: 100%|██████████| 157/157 [00:00<00:00, 401.53it/s]
# The loss for epoch 17 is 0.3153316110256128
# Epoch 18/50: 100%|██████████| 157/157 [00:00<00:00, 400.88it/s]
# The loss for epoch 18 is 0.31482834537746385
# Epoch 19/50: 100%|██████████| 157/157 [00:00<00:00, 389.47it/s]
# The loss for epoch 19 is 0.3192591823171824
# Epoch 20/50: 100%|██████████| 157/157 [00:00<00:00, 389.57it/s]
# The loss for epoch 20 is 0.32088463450782
# Epoch 21/50: 100%|██████████| 157/157 [00:00<00:00, 402.73it/s]
# The loss for epoch 21 is 0.3266160032944754
# 100%|██████████| 250/250 [00:00<00:00, 932.03it/s]
# Epoch 22/50: 100%|██████████| 157/157 [00:00<00:00, 402.46it/s]
# The loss for epoch 22 is 0.32889501692261547
# Epoch 23/50: 100%|██████████| 157/157 [00:00<00:00, 402.39it/s]
# The loss for epoch 23 is 0.3137693461612798
# Epoch 24/50: 100%|██████████| 157/157 [00:00<00:00, 400.44it/s]
# The loss for epoch 24 is 0.32812288764398545
# Epoch 25/50: 100%|██████████| 157/157 [00:00<00:00, 401.14it/s]
# The loss for epoch 25 is 0.3227709672646597
# Epoch 26/50: 100%|██████████| 157/157 [00:00<00:00, 402.54it/s]
# The loss for epoch 26 is 0.31708987458841875
# Epoch 27/50: 100%|██████████| 157/157 [00:00<00:00, 401.35it/s]
# The loss for epoch 27 is 0.33012600569054484
# Epoch 28/50: 100%|██████████| 157/157 [00:00<00:00, 401.06it/s]
# The loss for epoch 28 is 0.32567277195630595
# Epoch 29/50: 100%|██████████| 157/157 [00:00<00:00, 400.33it/s]
# The loss for epoch 29 is 0.3094490804360248
# Epoch 30/50: 100%|██████████| 157/157 [00:00<00:00, 401.28it/s]
# The loss for epoch 30 is 0.3314257976016961
# Epoch 31/50: 100%|██████████| 157/157 [00:00<00:00, 400.50it/s]
# The loss for epoch 31 is 0.32046474545495585
# 100%|██████████| 250/250 [00:00<00:00, 933.29it/s]
# Epoch 32/50: 100%|██████████| 157/157 [00:00<00:00, 401.56it/s]
# The loss for epoch 32 is 0.3239719442790374
# Epoch 33/50: 100%|██████████| 157/157 [00:00<00:00, 400.97it/s]
# The loss for epoch 33 is 0.3245224020211026
# Epoch 34/50: 100%|██████████| 157/157 [00:00<00:00, 401.48it/s]
# The loss for epoch 34 is 0.31949408957734704
# Epoch 35/50: 100%|██████████| 157/157 [00:00<00:00, 402.03it/s]
# The loss for epoch 35 is 0.32638763217255473
# Epoch 36/50: 100%|██████████| 157/157 [00:00<00:00, 400.03it/s]
# The loss for epoch 36 is 0.34462389949476346
# Epoch 37/50: 100%|██████████| 157/157 [00:00<00:00, 400.78it/s]
# The loss for epoch 37 is 0.31412177317542955
# Epoch 38/50: 100%|██████████| 157/157 [00:00<00:00, 400.14it/s]
# The loss for epoch 38 is 0.33347908867290244
# Epoch 39/50: 100%|██████████| 157/157 [00:00<00:00, 401.55it/s]
# The loss for epoch 39 is 0.33070590486750007
# Epoch 40/50: 100%|██████████| 157/157 [00:00<00:00, 400.99it/s]
# The loss for epoch 40 is 0.3224269640631974
# Epoch 41/50: 100%|██████████| 157/157 [00:00<00:00, 399.07it/s]
# The loss for epoch 41 is 0.3091805574949831
# 100%|██████████| 250/250 [00:00<00:00, 930.94it/s]
# Epoch 42/50: 100%|██████████| 157/157 [00:00<00:00, 403.78it/s]
# The loss for epoch 42 is 0.32787107198964804
# Epoch 43/50: 100%|██████████| 157/157 [00:00<00:00, 396.12it/s]
# The loss for epoch 43 is 0.3022365474025719
# Epoch 44/50: 100%|██████████| 157/157 [00:00<00:00, 395.80it/s]
# The loss for epoch 44 is 0.3114055342739448
# Epoch 45/50: 100%|██████████| 157/157 [00:00<00:00, 389.46it/s]
# The loss for epoch 45 is 0.33065172081114724
# Epoch 46/50: 100%|██████████| 157/157 [00:00<00:00, 393.83it/s]
# The loss for epoch 46 is 0.3232934729894623
# Epoch 47/50: 100%|██████████| 157/157 [00:00<00:00, 402.40it/s]
# The loss for epoch 47 is 0.31094601744553074
# Epoch 48/50: 100%|██████████| 157/157 [00:00<00:00, 401.66it/s]
# The loss for epoch 48 is 0.31043318193405867
# Epoch 49/50: 100%|██████████| 157/157 [00:00<00:00, 401.09it/s]
# The loss for epoch 49 is 0.3234507578308694
# Epoch 50/50: 100%|██████████| 157/157 [00:00<00:00, 402.07it/s]
# The loss for epoch 50 is 0.3059712090762332
# 100%|██████████| 250/250 [00:00<00:00, 936.33it/s]
# Training Report :
# +--------------------------+------------------------------------------------+
# | Key                      | Value                                          |
# +==========================+================================================+
# | num_epoch                | 50                                             |
# +--------------------------+------------------------------------------------+
# | batch_size               | 64                                             |
# +--------------------------+------------------------------------------------+
# | gradient_clip_threshhold | 1                                              |
# +--------------------------+------------------------------------------------+
# | eval_frequency           | 10                                             |
# +--------------------------+------------------------------------------------+
# | sample_size              | 1000                                           |
# +--------------------------+------------------------------------------------+
# | data_name                | [('mnist', 'Data/Densities/density_map_0.pt')] |
# +--------------------------+------------------------------------------------+
# | device                   | cuda                                           |
# +--------------------------+------------------------------------------------+
# | best loss achieved       | 0.3022365474025719                             |
# +--------------------------+------------------------------------------------+

# %%
pah = tinyDiff_builder.trainer.model_save_path
print(pah)
# Out:
# /Data/saadelhfr/MAP583/Project_tiny_diffusion/Outputs/Residual_only_date_2024-03-14_16_c7272e

# %%
import os 
import numpy as np
framse_path = os.path.join(pah, "frames")
framse_np = np.load(
"Outputs/Residual_only_date_2024-03-14_16_c7272e/framse.npy"
)

# %%
import matplotlib.pyplot as plt

for i in range(framse_np.shape[0]):
    plt.scatter(framse_np[i][:, 0], framse_np[i][:, 1] , s = 5)
    plt.show()

# %%
for _ in range(10) : 
    sampled = tinyDiff_builder.trainer.sample(1000)
    sampled_np = sampled.cpu().numpy()


    plt.scatter(sampled_np[:, 0], sampled_np[:, 1], s = 5)
    plt.show()
# Out:
# 100%|██████████| 250/250 [00:00<00:00, 813.76it/s]
# 100%|██████████| 250/250 [00:00<00:00, 900.48it/s]
# 100%|██████████| 250/250 [00:00<00:00, 913.80it/s]
# 100%|██████████| 250/250 [00:00<00:00, 911.84it/s]
# 100%|██████████| 250/250 [00:00<00:00, 920.30it/s]
# 100%|██████████| 250/250 [00:00<00:00, 907.76it/s]
# 100%|██████████| 250/250 [00:00<00:00, 909.48it/s]
# 100%|██████████| 250/250 [00:00<00:00, 921.93it/s]
# 100%|██████████| 250/250 [00:00<00:00, 916.72it/s]
# 100%|██████████| 250/250 [00:00<00:00, 915.24it/s]
