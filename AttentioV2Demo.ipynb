# %%
from src.layers.Models import TinyDiffusion 

from torch.utils.data import DataLoader
from src.data.BaseData import DataSetTinyDiffusion
from src.utils.manage_device import select_device
# Out:
# /Data/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
cfg = {'device': 'cuda', 
       'model_type': 
                {'model_name': 'Residual_with_attention'}, 
     'model': {'Model': 
               {'depth': 5, 'size': 256, 'hidden_dim':1200, 'output_dim': 2, 'pos_emb': 'sinusoidal', 'input_size': 2}, 
               'attention': 
               {'input_dim': 512, 'output_dim': 2, 'max_length': 100, 'size': 256}
               }, 
     'trainer': {'num_epoch':100, 'batch_size': 100, 'gradient_clip_threshhold': 1, 'eval_frequency': 10, 'sample_size': 1000, 'scale_train': 1, 'periodic_resets': 0, 'len_independant_data': 400}, 
     'dataset': {'number_data_points': 10000, 'joined': 1, 'name_dataset': [['dino', ''], ['mnist', 'density_map_0.pt']]}, 
     'optimizer': {'lr': 0.001, 'weight_decay':0}, 
     'Diffusion': {'num_timesteps':250, 'beta_start': 0.0001, 'beta_end': 0.02, 'beta_schedule': 'quadratic'}}

# %%
model_name = cfg["model_type"]["model_name"]
device = select_device(cfg['device'])
    # Correct way to merge dictionaries and add a new key in Python
model_config = {**cfg["model"], "device": device}
dataset_config = {**cfg["dataset"], "device": device}
dataset_config["name_dataset"] = [("dino", ""), ("moons", "")]
trainer_config = {
    **cfg["trainer"],
    "data_name": dataset_config["name_dataset"],
    "device": device,
}
optimizer_config = {**cfg["optimizer"]}
diff_config = {**cfg["Diffusion"], "device": device}

# %%
tinyDiff_builder = TinyDiffusion(
    model_name, model_config, trainer_config, optimizer_config, diff_config, device
)
print(tinyDiff_builder)
dataset = DataSetTinyDiffusion(**dataset_config)
print(dataset)
train_loader = DataLoader(
    dataset, batch_size=int(trainer_config["batch_size"]), shuffle=False
)
print(train_loader)
# Out:
# <src.layers.Models.TinyDiffusion object at 0x7f9ae2309510>
# [<src.data.CombinedData.CombinedDataset object at 0x7f9af401ff50>, <src.data.CombinedData.CombinedDataset object at 0x7f9ae6b6a110>]
# <src.data.BaseData.DataSetTinyDiffusion object at 0x7f9ae36fb050>
# <torch.utils.data.dataloader.DataLoader object at 0x7f9a9c309510>

# %%
tinyDiff_builder.train(train_loader)
# Out:
# Epoch 1/100: 100%|██████████| 200/200 [00:01<00:00, 198.40it/s]
# The loss for epoch 1 is 2.234376746118069
# 100%|██████████| 10/10 [00:07<00:00,  1.42it/s]
# Epoch 2/100: 100%|██████████| 200/200 [00:01<00:00, 199.73it/s]
# The loss for epoch 2 is 1.5684194409847259
# Epoch 3/100: 100%|██████████| 200/200 [00:01<00:00, 197.14it/s]
# The loss for epoch 3 is 1.478229983150959
# Epoch 4/100: 100%|██████████| 200/200 [00:00<00:00, 207.79it/s]
# The loss for epoch 4 is 1.49758934289217
# Epoch 5/100: 100%|██████████| 200/200 [00:00<00:00, 209.06it/s]
# The loss for epoch 5 is 1.4982729336619378
# Epoch 6/100: 100%|██████████| 200/200 [00:00<00:00, 208.92it/s]
# The loss for epoch 6 is 1.505547032058239
# Epoch 7/100: 100%|██████████| 200/200 [00:00<00:00, 209.20it/s]
# The loss for epoch 7 is 1.4871019589900971
# Epoch 8/100: 100%|██████████| 200/200 [00:00<00:00, 208.40it/s]
# The loss for epoch 8 is 1.5107847240567207
# Epoch 9/100: 100%|██████████| 200/200 [00:01<00:00, 191.52it/s]
# The loss for epoch 9 is 1.4449837198853492
# Epoch 10/100: 100%|██████████| 200/200 [00:00<00:00, 206.05it/s]
# The loss for epoch 10 is 1.4983118161559106
# Epoch 11/100: 100%|██████████| 200/200 [00:00<00:00, 205.83it/s]
# The loss for epoch 11 is 1.5199112597107887
# 100%|██████████| 10/10 [00:07<00:00,  1.38it/s]
# Epoch 12/100: 100%|██████████| 200/200 [00:01<00:00, 196.57it/s]
# The loss for epoch 12 is 1.4369659504294396
# Epoch 13/100: 100%|██████████| 200/200 [00:00<00:00, 205.19it/s]
# The loss for epoch 13 is 1.4875414383411407
# Epoch 14/100: 100%|██████████| 200/200 [00:01<00:00, 199.65it/s]
# The loss for epoch 14 is 1.4023711422085763
# Epoch 15/100: 100%|██████████| 200/200 [00:00<00:00, 205.25it/s]
# The loss for epoch 15 is 1.4804470279812814
# Epoch 16/100: 100%|██████████| 200/200 [00:00<00:00, 204.90it/s]
# The loss for epoch 16 is 1.4194680652022362
# Epoch 17/100: 100%|██████████| 200/200 [00:00<00:00, 204.02it/s]
# The loss for epoch 17 is 1.4491614577174188
# Epoch 18/100: 100%|██████████| 200/200 [00:00<00:00, 204.88it/s]
# The loss for epoch 18 is 1.4512689253687858
# Epoch 19/100: 100%|██████████| 200/200 [00:00<00:00, 203.44it/s]
# The loss for epoch 19 is 1.4321556642651558
# Epoch 20/100: 100%|██████████| 200/200 [00:00<00:00, 204.26it/s]
# The loss for epoch 20 is 1.4962058252096175
# Epoch 21/100: 100%|██████████| 200/200 [00:00<00:00, 205.11it/s]
# The loss for epoch 21 is 1.4449370890855788
# 100%|██████████| 10/10 [00:07<00:00,  1.35it/s]
# Epoch 22/100: 100%|██████████| 200/200 [00:00<00:00, 205.50it/s]
# The loss for epoch 22 is 1.458755941092968
# Epoch 23/100: 100%|██████████| 200/200 [00:00<00:00, 204.39it/s]
# The loss for epoch 23 is 1.4469606071710586
# Epoch 24/100: 100%|██████████| 200/200 [00:00<00:00, 205.13it/s]
# The loss for epoch 24 is 1.4433683100342751
# Epoch 25/100: 100%|██████████| 200/200 [00:00<00:00, 205.43it/s]
# The loss for epoch 25 is 1.448417249917984
# Epoch 26/100: 100%|██████████| 200/200 [00:00<00:00, 204.96it/s]
# The loss for epoch 26 is 1.422264940738678
# Epoch 27/100: 100%|██████████| 200/200 [00:00<00:00, 202.60it/s]
# The loss for epoch 27 is 1.4382622715830804
# Epoch 28/100: 100%|██████████| 200/200 [00:00<00:00, 201.51it/s]
# The loss for epoch 28 is 1.4392096948623658
# Epoch 29/100: 100%|██████████| 200/200 [00:00<00:00, 205.17it/s]
# The loss for epoch 29 is 1.4136167374253272
# Epoch 30/100: 100%|██████████| 200/200 [00:00<00:00, 205.57it/s]
# The loss for epoch 30 is 1.4199781543016434
# Epoch 31/100: 100%|██████████| 200/200 [00:00<00:00, 204.51it/s]
# The loss for epoch 31 is 1.6072386050224303
# 100%|██████████| 10/10 [00:07<00:00,  1.36it/s]
# Epoch 32/100: 100%|██████████| 200/200 [00:00<00:00, 204.40it/s]
# The loss for epoch 32 is 1.45107801258564
# Epoch 33/100: 100%|██████████| 200/200 [00:01<00:00, 192.54it/s]
# The loss for epoch 33 is 1.3719350457191468
# Epoch 34/100: 100%|██████████| 200/200 [00:00<00:00, 206.34it/s]
# The loss for epoch 34 is 1.4000774604082107
# Epoch 35/100: 100%|██████████| 200/200 [00:00<00:00, 206.25it/s]
# The loss for epoch 35 is 1.4494805335998535
# Epoch 36/100: 100%|██████████| 200/200 [00:00<00:00, 206.06it/s]
# The loss for epoch 36 is 1.4569313815236091
# Epoch 37/100: 100%|██████████| 200/200 [00:00<00:00, 207.18it/s]
# The loss for epoch 37 is 1.405465713441372
# Epoch 38/100: 100%|██████████| 200/200 [00:00<00:00, 206.43it/s]
# The loss for epoch 38 is 1.4179936996102334
# Epoch 39/100: 100%|██████████| 200/200 [00:00<00:00, 205.71it/s]
# The loss for epoch 39 is 1.3980487409234046
# Epoch 40/100: 100%|██████████| 200/200 [00:00<00:00, 206.95it/s]
# The loss for epoch 40 is 1.439348228573799
# Epoch 41/100: 100%|██████████| 200/200 [00:00<00:00, 206.96it/s]
# The loss for epoch 41 is 1.4416953080892563
# 100%|██████████| 10/10 [00:07<00:00,  1.38it/s]
# Epoch 42/100: 100%|██████████| 200/200 [00:00<00:00, 206.37it/s]
# The loss for epoch 42 is 1.439203611910343
# Epoch 43/100: 100%|██████████| 200/200 [00:00<00:00, 204.62it/s]
# The loss for epoch 43 is 1.4286584377288818
# Epoch 44/100: 100%|██████████| 200/200 [00:00<00:00, 206.04it/s]
# The loss for epoch 44 is 1.4156676483154298
# Epoch 45/100: 100%|██████████| 200/200 [00:00<00:00, 206.23it/s]
# The loss for epoch 45 is 1.416780916750431
# Epoch 46/100: 100%|██████████| 200/200 [00:00<00:00, 202.11it/s]
# The loss for epoch 46 is 1.402294553220272
# Epoch 47/100: 100%|██████████| 200/200 [00:00<00:00, 205.41it/s]
# The loss for epoch 47 is 1.4465073892474174
# Epoch 48/100: 100%|██████████| 200/200 [00:00<00:00, 206.54it/s]
# The loss for epoch 48 is 1.4143318477272988
# Epoch 49/100: 100%|██████████| 200/200 [00:00<00:00, 207.03it/s]
# The loss for epoch 49 is 1.4068849217891692
# Epoch 50/100: 100%|██████████| 200/200 [00:00<00:00, 207.19it/s]
# The loss for epoch 50 is 1.437737685739994
# Epoch 51/100: 100%|██████████| 200/200 [00:00<00:00, 206.07it/s]
# The loss for epoch 51 is 1.3771377292275429
# 100%|██████████| 10/10 [00:07<00:00,  1.38it/s]
# Epoch 52/100: 100%|██████████| 200/200 [00:00<00:00, 212.59it/s]
# The loss for epoch 52 is 1.3919316470623015
# Epoch 53/100: 100%|██████████| 200/200 [00:00<00:00, 211.95it/s]
# The loss for epoch 53 is 1.416481220126152
# Epoch 54/100: 100%|██████████| 200/200 [00:00<00:00, 211.90it/s]
# The loss for epoch 54 is 1.4092963606119155
# Epoch 55/100: 100%|██████████| 200/200 [00:00<00:00, 212.07it/s]
# The loss for epoch 55 is 1.4255185982584953
# Epoch 56/100: 100%|██████████| 200/200 [00:00<00:00, 205.81it/s]
# The loss for epoch 56 is 1.4113097968697548
# Epoch 57/100: 100%|██████████| 200/200 [00:00<00:00, 206.52it/s]
# The loss for epoch 57 is 1.4202520260214806
# Epoch 58/100: 100%|██████████| 200/200 [00:00<00:00, 206.26it/s]
# The loss for epoch 58 is 1.4355294707417487
# Epoch 59/100: 100%|██████████| 200/200 [00:00<00:00, 207.22it/s]
# The loss for epoch 59 is 1.391060860157013
# Epoch 60/100: 100%|██████████| 200/200 [00:00<00:00, 207.20it/s]
# The loss for epoch 60 is 1.399405795931816
# Epoch 61/100: 100%|██████████| 200/200 [00:00<00:00, 202.64it/s]
# The loss for epoch 61 is 1.4104859748482703
# 100%|██████████| 10/10 [00:07<00:00,  1.38it/s]
# Epoch 62/100: 100%|██████████| 200/200 [00:00<00:00, 205.63it/s]
# The loss for epoch 62 is 1.4187869346141815
# Epoch 63/100: 100%|██████████| 200/200 [00:00<00:00, 206.38it/s]
# The loss for epoch 63 is 1.3915884917974473
# Epoch 64/100: 100%|██████████| 200/200 [00:00<00:00, 206.44it/s]
# The loss for epoch 64 is 1.389783461689949
# Epoch 65/100: 100%|██████████| 200/200 [00:00<00:00, 200.57it/s]
# The loss for epoch 65 is 1.4192611742019654
# Epoch 66/100: 100%|██████████| 200/200 [00:00<00:00, 206.03it/s]
# The loss for epoch 66 is 1.4009562480449675
# Epoch 67/100: 100%|██████████| 200/200 [00:00<00:00, 205.85it/s]
# The loss for epoch 67 is 1.3977379709482194
# Epoch 68/100: 100%|██████████| 200/200 [00:00<00:00, 205.85it/s]
# The loss for epoch 68 is 1.4144650778174401
# Epoch 69/100: 100%|██████████| 200/200 [00:00<00:00, 207.07it/s]
# The loss for epoch 69 is 1.4177638387680054
# Epoch 70/100: 100%|██████████| 200/200 [00:00<00:00, 206.63it/s]
# The loss for epoch 70 is 1.3906636607646943
# Epoch 71/100: 100%|██████████| 200/200 [00:00<00:00, 205.79it/s]
# The loss for epoch 71 is 1.4243752375245093
# 100%|██████████| 10/10 [00:07<00:00,  1.38it/s]
# Epoch 72/100: 100%|██████████| 200/200 [00:00<00:00, 205.91it/s]
# The loss for epoch 72 is 1.4088066279888154
# Epoch 73/100: 100%|██████████| 200/200 [00:00<00:00, 203.96it/s]
# The loss for epoch 73 is 1.3883495742082597
# Epoch 74/100: 100%|██████████| 200/200 [00:00<00:00, 205.88it/s]
# The loss for epoch 74 is 1.4214600053429605
# Epoch 75/100: 100%|██████████| 200/200 [00:00<00:00, 206.26it/s]
# The loss for epoch 75 is 1.393185667693615
# Epoch 76/100: 100%|██████████| 200/200 [00:00<00:00, 206.00it/s]
# The loss for epoch 76 is 1.4122233214974402
# Epoch 77/100: 100%|██████████| 200/200 [00:00<00:00, 205.16it/s]
# The loss for epoch 77 is 1.3758959364891052
# Epoch 78/100: 100%|██████████| 200/200 [00:00<00:00, 205.61it/s]
# The loss for epoch 78 is 1.4363594156503678
# Epoch 79/100: 100%|██████████| 200/200 [00:00<00:00, 205.86it/s]
# The loss for epoch 79 is 1.3886843144893646
# Epoch 80/100: 100%|██████████| 200/200 [00:01<00:00, 190.72it/s]
# The loss for epoch 80 is 1.3544289204478264
# Epoch 81/100: 100%|██████████| 200/200 [00:00<00:00, 211.76it/s]
# The loss for epoch 81 is 1.4502776873111725
# 100%|██████████| 10/10 [00:07<00:00,  1.42it/s]
# Epoch 82/100: 100%|██████████| 200/200 [00:00<00:00, 209.76it/s]
# The loss for epoch 82 is 1.378995987176895
# Epoch 83/100: 100%|██████████| 200/200 [00:00<00:00, 208.33it/s]
# The loss for epoch 83 is 1.4029434970021248
# Epoch 84/100: 100%|██████████| 200/200 [00:00<00:00, 204.67it/s]
# The loss for epoch 84 is 1.4071381694078446
# Epoch 85/100: 100%|██████████| 200/200 [00:00<00:00, 209.57it/s]
# The loss for epoch 85 is 1.4375244456529617
# Epoch 86/100: 100%|██████████| 200/200 [00:00<00:00, 208.66it/s]
# The loss for epoch 86 is 1.435111391544342
# Epoch 87/100: 100%|██████████| 200/200 [00:00<00:00, 209.48it/s]
# The loss for epoch 87 is 1.3931344681978226
# Epoch 88/100: 100%|██████████| 200/200 [00:00<00:00, 209.74it/s]
# The loss for epoch 88 is 1.4177553725242615
# Epoch 89/100: 100%|██████████| 200/200 [00:00<00:00, 208.94it/s]
# The loss for epoch 89 is 1.361382661163807
# Epoch 90/100: 100%|██████████| 200/200 [00:00<00:00, 208.67it/s]
# The loss for epoch 90 is 1.3768413922190665
# Epoch 91/100: 100%|██████████| 200/200 [00:00<00:00, 209.18it/s]
# The loss for epoch 91 is 1.428020104765892
# 100%|██████████| 10/10 [00:07<00:00,  1.42it/s]
# Epoch 92/100: 100%|██████████| 200/200 [00:00<00:00, 210.45it/s]
# The loss for epoch 92 is 1.409908794760704
# Epoch 93/100: 100%|██████████| 200/200 [00:00<00:00, 209.55it/s]
# The loss for epoch 93 is 1.4281774592399596
# Epoch 94/100: 100%|██████████| 200/200 [00:00<00:00, 209.40it/s]
# The loss for epoch 94 is 1.4087486404180527
# Epoch 95/100: 100%|██████████| 200/200 [00:00<00:00, 208.87it/s]
# The loss for epoch 95 is 1.3935673093795777
# Epoch 96/100: 100%|██████████| 200/200 [00:00<00:00, 209.32it/s]
# The loss for epoch 96 is 1.3767273178696633
# Epoch 97/100: 100%|██████████| 200/200 [00:00<00:00, 209.16it/s]
# The loss for epoch 97 is 1.4019274291396142
# Epoch 98/100: 100%|██████████| 200/200 [00:00<00:00, 210.01it/s]
# The loss for epoch 98 is 1.3715782046318055
# Epoch 99/100: 100%|██████████| 200/200 [00:00<00:00, 205.85it/s]
# The loss for epoch 99 is 1.3857610675692558
# Epoch 100/100: 100%|██████████| 200/200 [00:00<00:00, 207.23it/s]
# The loss for epoch 100 is 1.3651543390750884
# 100%|██████████| 10/10 [00:07<00:00,  1.43it/s]
# Training Report :
# +--------------------------+-------------------------------+
# | Key                      | Value                         |
# +==========================+===============================+
# | num_epoch                | 100                           |
# +--------------------------+-------------------------------+
# | batch_size               | 100                           |
# +--------------------------+-------------------------------+
# | gradient_clip_threshhold | 1                             |
# +--------------------------+-------------------------------+
# | eval_frequency           | 10                            |
# +--------------------------+-------------------------------+
# | sample_size              | 1000                          |
# +--------------------------+-------------------------------+
# | scale_train              | 1                             |
# +--------------------------+-------------------------------+
# | periodic_resets          | 0                             |
# +--------------------------+-------------------------------+
# | len_independant_data     | 400                           |
# +--------------------------+-------------------------------+
# | data_name                | [('dino', ''), ('moons', '')] |
# +--------------------------+-------------------------------+
# | device                   | cuda                          |
# +--------------------------+-------------------------------+
# | best loss achieved       | 1.3544289204478264            |
# +--------------------------+-------------------------------+

# %%
import torch
import os 
checkpoints_dir_path = "Outputs/Residual_with_attention_date_2024-03-15_00_000a70/Checkpoints"
path_to_best_model = tinyDiff_builder.trainer.checkpoints_dir_path.split('Project_tiny_diffusion/')[-1]
path_to_best_model_attention = os.path.join(path_to_best_model , 'attention_best_loss.pth')
path_to_best_model_model = os.path.join(path_to_best_model , 'model_best_loss.pth')
tinyDiff_builder.model.load_state_dict(torch.load(path_to_best_model_model))
tinyDiff_builder.attention.load_state_dict(torch.load(path_to_best_model_attention))
# Out:
# <All keys matched successfully>

# %%
pah = tinyDiff_builder.trainer.model_save_path.split('Project_tiny_diffusion/')[-1]
print(pah)
# Out:
# Outputs/Residual_with_attention_date_2024-03-15_14_95c9b1

# %%
import os 
import numpy as np
framse_path = os.path.join(pah, "framse.npy")
framse_np = np.load(
    framse_path
)

# %%
import matplotlib.pyplot as plt


framse_np_1 = framse_np[0]
framse_np_2 = framse_np[-1]

fig, axs = plt.subplots(5, 2, figsize=(15, 15))

for i, ax in enumerate(axs.flat):
    ax.scatter(framse_np[i, :, 0], framse_np[i, :, 1], s=2)
    ax.set_title(f"Scatter Plot {i * 10}")

plt.tight_layout()
plt.show()

# %%
# sampleing : 


fig, axs = plt.subplots(5, 2, figsize=(15, 15))
for i, ax in enumerate(axs.flat):
    sample = tinyDiff_builder.trainer.sample(3000 ) 
    
    sample_np = np.concatenate(sample , axis=0)

    ax.scatter(sample_np[:, 0], sample_np[:, 1] , s = 3)
    ax.set_title(f"Scatter Plot of a sampled example")
plt.tight_layout()
plt.show()
# Out:
# 100%|██████████| 30/30 [00:21<00:00,  1.42it/s]
# 100%|██████████| 30/30 [00:21<00:00,  1.42it/s]
# 100%|██████████| 30/30 [00:21<00:00,  1.43it/s]
# 100%|██████████| 30/30 [00:21<00:00,  1.43it/s]
# 100%|██████████| 30/30 [00:21<00:00,  1.43it/s]
# 100%|██████████| 30/30 [00:21<00:00,  1.43it/s]
# 100%|██████████| 30/30 [00:20<00:00,  1.43it/s]
# 100%|██████████| 30/30 [00:20<00:00,  1.43it/s]
# 100%|██████████| 30/30 [00:21<00:00,  1.43it/s]
# 100%|██████████| 30/30 [00:21<00:00,  1.41it/s]
