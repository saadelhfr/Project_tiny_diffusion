# %%
from src.layers.Models import TinyDiffusion 

from torch.utils.data import DataLoader
from src.data.BaseData import DataSetTinyDiffusion
from src.utils.manage_device import select_device
# Out:
# /Data/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
cfg = {'device': 'cuda', 
    'model_type': {'model_name': 'Residual_with_old_attention'}, 
    'model': {'Model': {'depth': 3, 'size': 256, 'hidden_dim': 800, 'output_dim': 2, 'input_size': 2, 'pos_emb': 'sinusoidal'}, 
           'attention': {'max_length': 1000, 'input_dim': 512, 'output_dim': 2}}, 
    'trainer': {'num_epoch': 150, 'batch_size': 250, 'gradient_clip_threshhold': 1, 'eval_frequency': 10, 'sample_size': 3000}, 
    'dataset': {'number_data_points': 100000, 'joined': 1, 'name_dataset': [['dino', ''], ['mnist', 'density_map_0.pt']]}, 
    'optimizer': {'lr': 0.0001, 'weight_decay': 5e-10}, 'Diffusion': {'num_timesteps': 250, 'beta_start': 0.0001, 'beta_end': 0.02, 'beta_schedule': 'linear'}}

# %%
model_name = cfg["model_type"]["model_name"]
device = select_device(cfg['device'])
    # Correct way to merge dictionaries and add a new key in Python
model_config = {**cfg["model"], "device": device}
dataset_config = {**cfg["dataset"], "device": device}
dataset_config["name_dataset"] = [("moons", ""), ("dino", "")]
trainer_config = {
    **cfg["trainer"],
    "data_name": dataset_config["name_dataset"],
    "device": device,
}
optimizer_config = {**cfg["optimizer"]}
diff_config = {**cfg["Diffusion"], "device": device}

# %%
tinyDiff_builder = TinyDiffusion(
    model_name, model_config, trainer_config, optimizer_config, diff_config, device
)
print(tinyDiff_builder)
dataset = DataSetTinyDiffusion(**dataset_config)
print(dataset)
train_loader = DataLoader(
    dataset, batch_size=int(trainer_config["batch_size"]), shuffle=False
)
print(train_loader)
tinyDiff_builder.train(train_loader)
# Out:
# <src.layers.Models.TinyDiffusion object at 0x7f3539772e90>
# [<src.data.CombinedData.CombinedDataset object at 0x7f35391b42d0>, <src.data.CombinedData.CombinedDataset object at 0x7f34fa7dab50>]
# <src.data.BaseData.DataSetTinyDiffusion object at 0x7f34f9270350>
# <torch.utils.data.dataloader.DataLoader object at 0x7f34f9e64dd0>
# Epoch 1/150: 100%|██████████| 800/800 [00:04<00:00, 185.82it/s]
# The loss for epoch 1 is 2.1747483273744583
# 100%|██████████| 12/12 [00:05<00:00,  2.27it/s]
# Epoch 2/150: 100%|██████████| 800/800 [00:04<00:00, 193.29it/s]
# The loss for epoch 2 is 1.94715784278512
# Epoch 3/150: 100%|██████████| 800/800 [00:04<00:00, 192.84it/s]
# The loss for epoch 3 is 1.7125340577960015
# Epoch 4/150: 100%|██████████| 800/800 [00:04<00:00, 195.79it/s]
# The loss for epoch 4 is 1.6792872770428657
# Epoch 5/150: 100%|██████████| 800/800 [00:04<00:00, 190.79it/s]
# The loss for epoch 5 is 1.4949323367774487
# Epoch 6/150: 100%|██████████| 800/800 [00:04<00:00, 194.17it/s]
# The loss for epoch 6 is 1.4703673736155034
# Epoch 7/150: 100%|██████████| 800/800 [00:04<00:00, 194.99it/s]
# The loss for epoch 7 is 1.4524791809171438
# Epoch 8/150: 100%|██████████| 800/800 [00:03<00:00, 202.28it/s]
# The loss for epoch 8 is 1.328527118563652
# Epoch 9/150: 100%|██████████| 800/800 [00:04<00:00, 194.90it/s]
# The loss for epoch 9 is 1.2865906511545182
# Epoch 10/150: 100%|██████████| 800/800 [00:04<00:00, 194.30it/s]
# The loss for epoch 10 is 1.2928642565906048
# Epoch 11/150: 100%|██████████| 800/800 [00:04<00:00, 192.75it/s]
# The loss for epoch 11 is 1.2719840182214974
# 100%|██████████| 12/12 [00:05<00:00,  2.27it/s]
# Epoch 12/150: 100%|██████████| 800/800 [00:04<00:00, 197.64it/s]
# The loss for epoch 12 is 1.1455003840625286
# Epoch 13/150: 100%|██████████| 800/800 [00:04<00:00, 190.08it/s]
# The loss for epoch 13 is 1.1769462150782346
# Epoch 14/150: 100%|██████████| 800/800 [00:04<00:00, 198.24it/s]
# The loss for epoch 14 is 1.1645223789662122
# Epoch 15/150: 100%|██████████| 800/800 [00:04<00:00, 199.36it/s]
# The loss for epoch 15 is 1.1742858150303364
# Epoch 16/150: 100%|██████████| 800/800 [00:04<00:00, 192.64it/s]
# The loss for epoch 16 is 1.0821993117332458
# Epoch 17/150: 100%|██████████| 800/800 [00:04<00:00, 194.36it/s]
# The loss for epoch 17 is 1.084956028625369
# Epoch 18/150: 100%|██████████| 800/800 [00:04<00:00, 194.02it/s]
# The loss for epoch 18 is 1.1470665192753076
# Epoch 19/150: 100%|██████████| 800/800 [00:04<00:00, 198.39it/s]
# The loss for epoch 19 is 1.170743717163801
# Epoch 20/150: 100%|██████████| 800/800 [00:04<00:00, 194.37it/s]
# The loss for epoch 20 is 1.0430258449614047
# Epoch 21/150: 100%|██████████| 800/800 [00:04<00:00, 193.32it/s]
# The loss for epoch 21 is 1.0852920103520154
# 100%|██████████| 12/12 [00:05<00:00,  2.28it/s]
# Epoch 22/150: 100%|██████████| 800/800 [00:04<00:00, 194.78it/s]
# The loss for epoch 22 is 1.061312081873417
# Epoch 23/150: 100%|██████████| 800/800 [00:04<00:00, 197.51it/s]
# The loss for epoch 23 is 1.0673748596161603
# Epoch 24/150: 100%|██████████| 800/800 [00:04<00:00, 194.24it/s]
# The loss for epoch 24 is 1.068880548134446
# Epoch 25/150: 100%|██████████| 800/800 [00:04<00:00, 192.97it/s]
# The loss for epoch 25 is 1.0459743329584599
# Epoch 26/150: 100%|██████████| 800/800 [00:04<00:00, 192.77it/s]
# The loss for epoch 26 is 1.0353435002565383
# Epoch 27/150: 100%|██████████| 800/800 [00:04<00:00, 198.50it/s]
# The loss for epoch 27 is 1.0186382837593555
# Epoch 28/150: 100%|██████████| 800/800 [00:04<00:00, 192.49it/s]
# The loss for epoch 28 is 1.001686379134655
# Epoch 29/150: 100%|██████████| 800/800 [00:04<00:00, 195.60it/s]
# The loss for epoch 29 is 1.0677655612230301
# Epoch 30/150: 100%|██████████| 800/800 [00:04<00:00, 195.62it/s]
# The loss for epoch 30 is 1.0068821516484021
# Epoch 31/150: 100%|██████████| 800/800 [00:04<00:00, 198.61it/s]
# The loss for epoch 31 is 1.0467978215515614
# 100%|██████████| 12/12 [00:05<00:00,  2.31it/s]
# Epoch 32/150: 100%|██████████| 800/800 [00:04<00:00, 194.56it/s]
# The loss for epoch 32 is 1.0181201414763927
# Epoch 33/150: 100%|██████████| 800/800 [00:04<00:00, 193.88it/s]
# The loss for epoch 33 is 0.9665439854860306
# Epoch 34/150: 100%|██████████| 800/800 [00:04<00:00, 195.24it/s]
# The loss for epoch 34 is 1.031880944788456
# Epoch 35/150: 100%|██████████| 800/800 [00:04<00:00, 199.20it/s]
# The loss for epoch 35 is 0.9867059823423624
# Epoch 36/150: 100%|██████████| 800/800 [00:04<00:00, 195.84it/s]
# The loss for epoch 36 is 1.0315117742717266
# Epoch 37/150: 100%|██████████| 800/800 [00:04<00:00, 194.75it/s]
# The loss for epoch 37 is 0.9840448788106442
# Epoch 38/150: 100%|██████████| 800/800 [00:03<00:00, 200.55it/s]
# The loss for epoch 38 is 0.9869183571487665
# Epoch 39/150: 100%|██████████| 800/800 [00:04<00:00, 195.95it/s]
# The loss for epoch 39 is 1.0325696273595095
# Epoch 40/150: 100%|██████████| 800/800 [00:04<00:00, 192.67it/s]
# The loss for epoch 40 is 0.9306857871264219
# Epoch 41/150: 100%|██████████| 800/800 [00:04<00:00, 195.18it/s]
# The loss for epoch 41 is 0.9878802775144577
# 100%|██████████| 12/12 [00:05<00:00,  2.32it/s]
# Epoch 42/150: 100%|██████████| 800/800 [00:04<00:00, 198.58it/s]
# The loss for epoch 42 is 0.9812578140497208
# Epoch 43/150: 100%|██████████| 800/800 [00:04<00:00, 192.93it/s]
# The loss for epoch 43 is 1.0065589749515056
# Epoch 44/150: 100%|██████████| 800/800 [00:04<00:00, 192.52it/s]
# The loss for epoch 44 is 0.9737091536968946
# Epoch 45/150: 100%|██████████| 800/800 [00:04<00:00, 193.18it/s]
# The loss for epoch 45 is 0.9772687447220088
# Epoch 46/150: 100%|██████████| 800/800 [00:04<00:00, 198.75it/s]
# The loss for epoch 46 is 1.0088426717594265
# Epoch 47/150: 100%|██████████| 800/800 [00:04<00:00, 191.87it/s]
# The loss for epoch 47 is 0.9751477514058352
# Epoch 48/150: 100%|██████████| 800/800 [00:04<00:00, 194.13it/s]
# The loss for epoch 48 is 0.9551475128158927
# Epoch 49/150: 100%|██████████| 800/800 [00:04<00:00, 193.27it/s]
# The loss for epoch 49 is 0.9681090994924307
# Epoch 50/150: 100%|██████████| 800/800 [00:04<00:00, 199.22it/s]
# The loss for epoch 50 is 0.9155843948498368
# Epoch 51/150: 100%|██████████| 800/800 [00:04<00:00, 197.06it/s]
# The loss for epoch 51 is 0.9762621813118458
# 100%|██████████| 12/12 [00:05<00:00,  2.36it/s]
# Epoch 52/150: 100%|██████████| 800/800 [00:03<00:00, 201.67it/s]
# The loss for epoch 52 is 0.938631271712482
# Epoch 53/150: 100%|██████████| 800/800 [00:03<00:00, 201.66it/s]
# The loss for epoch 53 is 0.9633970274329186
# Epoch 54/150: 100%|██████████| 800/800 [00:03<00:00, 204.86it/s]
# The loss for epoch 54 is 0.9488658790811896
# Epoch 55/150: 100%|██████████| 800/800 [00:04<00:00, 198.38it/s]
# The loss for epoch 55 is 0.9130375478863716
# Epoch 56/150: 100%|██████████| 800/800 [00:04<00:00, 194.09it/s]
# The loss for epoch 56 is 0.9674284600913524
# Epoch 57/150: 100%|██████████| 800/800 [00:04<00:00, 196.10it/s]
# The loss for epoch 57 is 0.9268891054913402
# Epoch 58/150: 100%|██████████| 800/800 [00:03<00:00, 200.51it/s]
# The loss for epoch 58 is 0.9241303096562624
# Epoch 59/150: 100%|██████████| 800/800 [00:04<00:00, 194.26it/s]
# The loss for epoch 59 is 0.9238811723962426
# Epoch 60/150: 100%|██████████| 800/800 [00:04<00:00, 194.57it/s]
# The loss for epoch 60 is 0.8758116865083575
# Epoch 61/150: 100%|██████████| 800/800 [00:04<00:00, 195.06it/s]
# The loss for epoch 61 is 0.9321115509048105
# 100%|██████████| 12/12 [00:05<00:00,  2.31it/s]
# Epoch 62/150: 100%|██████████| 800/800 [00:03<00:00, 200.37it/s]
# The loss for epoch 62 is 0.926472429767251
# Epoch 63/150: 100%|██████████| 800/800 [00:04<00:00, 194.22it/s]
# The loss for epoch 63 is 0.9326807954162359
# Epoch 64/150: 100%|██████████| 800/800 [00:04<00:00, 196.01it/s]
# The loss for epoch 64 is 0.9204555256590247
# Epoch 65/150: 100%|██████████| 800/800 [00:03<00:00, 200.49it/s]
# The loss for epoch 65 is 0.8804934888035059
# Epoch 66/150: 100%|██████████| 800/800 [00:04<00:00, 192.05it/s]
# The loss for epoch 66 is 0.8662117666006088
# Epoch 67/150: 100%|██████████| 800/800 [00:04<00:00, 193.25it/s]
# The loss for epoch 67 is 0.917827151067555
# Epoch 68/150: 100%|██████████| 800/800 [00:04<00:00, 188.04it/s]
# The loss for epoch 68 is 0.9228111447617412
# Epoch 69/150: 100%|██████████| 800/800 [00:04<00:00, 189.12it/s]
# The loss for epoch 69 is 0.8707070728093386
# Epoch 70/150: 100%|██████████| 800/800 [00:04<00:00, 193.75it/s]
# The loss for epoch 70 is 0.8473473359048367
# Epoch 71/150: 100%|██████████| 800/800 [00:04<00:00, 193.51it/s]
# The loss for epoch 71 is 0.9495624322742223
# 100%|██████████| 12/12 [00:05<00:00,  2.32it/s]
# Epoch 72/150: 100%|██████████| 800/800 [00:04<00:00, 193.57it/s]
# The loss for epoch 72 is 0.8700974686965346
# Epoch 73/150: 100%|██████████| 800/800 [00:04<00:00, 199.49it/s]
# The loss for epoch 73 is 0.9288108161240816
# Epoch 74/150: 100%|██████████| 800/800 [00:04<00:00, 194.61it/s]
# The loss for epoch 74 is 0.8827641419395804
# Epoch 75/150: 100%|██████████| 800/800 [00:04<00:00, 193.70it/s]
# The loss for epoch 75 is 0.8511769229620695
# Epoch 76/150: 100%|██████████| 800/800 [00:04<00:00, 195.03it/s]
# The loss for epoch 76 is 0.899418710693717
# Epoch 77/150: 100%|██████████| 800/800 [00:04<00:00, 198.50it/s]
# The loss for epoch 77 is 0.903203880675137
# Epoch 78/150: 100%|██████████| 800/800 [00:04<00:00, 193.99it/s]
# The loss for epoch 78 is 0.8575161185115576
# Epoch 79/150: 100%|██████████| 800/800 [00:04<00:00, 191.28it/s]
# The loss for epoch 79 is 0.925618102952838
# Epoch 80/150: 100%|██████████| 800/800 [00:04<00:00, 187.36it/s]
# The loss for epoch 80 is 0.9131181410327553
# Epoch 81/150: 100%|██████████| 800/800 [00:04<00:00, 196.31it/s]
# The loss for epoch 81 is 0.7994776388853788
# 100%|██████████| 12/12 [00:05<00:00,  2.23it/s]
# Epoch 82/150: 100%|██████████| 800/800 [00:04<00:00, 186.65it/s]
# The loss for epoch 82 is 0.8624814668893814
# Epoch 83/150: 100%|██████████| 800/800 [00:04<00:00, 194.87it/s]
# The loss for epoch 83 is 0.8948189890310169
# Epoch 84/150: 100%|██████████| 800/800 [00:04<00:00, 194.19it/s]
# The loss for epoch 84 is 0.8603626514896751
# Epoch 85/150: 100%|██████████| 800/800 [00:03<00:00, 200.35it/s]
# The loss for epoch 85 is 0.8375960535854101
# Epoch 86/150: 100%|██████████| 800/800 [00:04<00:00, 197.53it/s]
# The loss for epoch 86 is 0.8304310702085494
# Epoch 87/150: 100%|██████████| 800/800 [00:04<00:00, 184.44it/s]
# The loss for epoch 87 is 0.8447574455812573
# Epoch 88/150: 100%|██████████| 800/800 [00:03<00:00, 203.11it/s]
# The loss for epoch 88 is 0.8534184518419207
# Epoch 89/150: 100%|██████████| 800/800 [00:04<00:00, 197.66it/s]
# The loss for epoch 89 is 0.7946677610948681
# Epoch 90/150: 100%|██████████| 800/800 [00:04<00:00, 198.07it/s]
# The loss for epoch 90 is 0.8713438644297421
# Epoch 91/150: 100%|██████████| 800/800 [00:04<00:00, 198.38it/s]
# The loss for epoch 91 is 0.8356730168908835
# 100%|██████████| 12/12 [00:05<00:00,  2.39it/s]
# Epoch 92/150: 100%|██████████| 800/800 [00:03<00:00, 203.16it/s]
# The loss for epoch 92 is 0.8481051653698086
# Epoch 93/150: 100%|██████████| 800/800 [00:04<00:00, 194.73it/s]
# The loss for epoch 93 is 0.8262885335460305
# Epoch 94/150: 100%|██████████| 800/800 [00:04<00:00, 190.08it/s]
# The loss for epoch 94 is 0.8182332196757197
# Epoch 95/150: 100%|██████████| 800/800 [00:04<00:00, 196.48it/s]
# The loss for epoch 95 is 0.8514224450141191
# Epoch 96/150: 100%|██████████| 800/800 [00:03<00:00, 201.69it/s]
# The loss for epoch 96 is 0.8286177044138312
# Epoch 97/150: 100%|██████████| 800/800 [00:04<00:00, 196.83it/s]
# The loss for epoch 97 is 0.8397891364246607
# Epoch 98/150: 100%|██████████| 800/800 [00:04<00:00, 197.06it/s]
# The loss for epoch 98 is 0.7944529470466077
# Epoch 99/150: 100%|██████████| 800/800 [00:04<00:00, 197.38it/s]
# The loss for epoch 99 is 0.8421525370180607
# Epoch 100/150: 100%|██████████| 800/800 [00:03<00:00, 202.34it/s]
# The loss for epoch 100 is 0.8303500809445977
# Epoch 101/150: 100%|██████████| 800/800 [00:04<00:00, 170.53it/s]
# The loss for epoch 101 is 0.8202412286102772
# 100%|██████████| 12/12 [00:05<00:00,  2.21it/s]
# Epoch 102/150: 100%|██████████| 800/800 [00:04<00:00, 193.49it/s]
# The loss for epoch 102 is 0.8115724763311446
# Epoch 103/150: 100%|██████████| 800/800 [00:04<00:00, 195.18it/s]
# The loss for epoch 103 is 0.8337285394966603
# Epoch 104/150: 100%|██████████| 800/800 [00:04<00:00, 181.49it/s]
# The loss for epoch 104 is 0.8348597155027091
# Epoch 105/150: 100%|██████████| 800/800 [00:04<00:00, 188.67it/s]
# The loss for epoch 105 is 0.8059966462999583
# Epoch 106/150: 100%|██████████| 800/800 [00:04<00:00, 190.47it/s]
# The loss for epoch 106 is 0.7701043778695166
# Epoch 107/150: 100%|██████████| 800/800 [00:04<00:00, 194.13it/s]
# The loss for epoch 107 is 0.8088006458431483
# Epoch 108/150: 100%|██████████| 800/800 [00:04<00:00, 197.89it/s]
# The loss for epoch 108 is 0.7698930572792888
# Epoch 109/150: 100%|██████████| 800/800 [00:04<00:00, 195.62it/s]
# The loss for epoch 109 is 0.8050704254209995
# Epoch 110/150: 100%|██████████| 800/800 [00:04<00:00, 195.97it/s]
# The loss for epoch 110 is 0.7788104744069279
# Epoch 111/150: 100%|██████████| 800/800 [00:04<00:00, 194.03it/s]
# The loss for epoch 111 is 0.7942620501369237
# 100%|██████████| 12/12 [00:05<00:00,  2.38it/s]
# Epoch 112/150: 100%|██████████| 800/800 [00:03<00:00, 200.10it/s]
# The loss for epoch 112 is 0.8179758728221059
# Epoch 113/150: 100%|██████████| 800/800 [00:04<00:00, 194.63it/s]
# The loss for epoch 113 is 0.8144772383309901
# Epoch 114/150: 100%|██████████| 800/800 [00:04<00:00, 195.94it/s]
# The loss for epoch 114 is 0.8254397901259363
# Epoch 115/150: 100%|██████████| 800/800 [00:04<00:00, 198.89it/s]
# The loss for epoch 115 is 0.7823170523568987
# Epoch 116/150: 100%|██████████| 800/800 [00:04<00:00, 193.47it/s]
# The loss for epoch 116 is 0.7594561853557825
# Epoch 117/150: 100%|██████████| 800/800 [00:04<00:00, 195.24it/s]
# The loss for epoch 117 is 0.801578251466155
# Epoch 118/150: 100%|██████████| 800/800 [00:04<00:00, 193.64it/s]
# The loss for epoch 118 is 0.8302163433730603
# Epoch 119/150: 100%|██████████| 800/800 [00:03<00:00, 200.01it/s]
# The loss for epoch 119 is 0.8112048154175282
# Epoch 120/150: 100%|██████████| 800/800 [00:04<00:00, 195.94it/s]
# The loss for epoch 120 is 0.7827600716985762
# Epoch 121/150: 100%|██████████| 800/800 [00:04<00:00, 194.33it/s]
# The loss for epoch 121 is 0.8206431572437286
# 100%|██████████| 12/12 [00:05<00:00,  2.38it/s]
# Epoch 122/150: 100%|██████████| 800/800 [00:04<00:00, 193.93it/s]
# The loss for epoch 122 is 0.7951275337487459
# Epoch 123/150: 100%|██████████| 800/800 [00:03<00:00, 200.07it/s]
# The loss for epoch 123 is 0.8093412397578359
# Epoch 124/150: 100%|██████████| 800/800 [00:04<00:00, 195.12it/s]
# The loss for epoch 124 is 0.7880553308315575
# Epoch 125/150: 100%|██████████| 800/800 [00:04<00:00, 194.13it/s]
# The loss for epoch 125 is 0.7867189389541746
# Epoch 126/150: 100%|██████████| 800/800 [00:04<00:00, 194.95it/s]
# The loss for epoch 126 is 0.7960733450576662
# Epoch 127/150: 100%|██████████| 800/800 [00:04<00:00, 198.89it/s]
# The loss for epoch 127 is 0.8244261886887252
# Epoch 128/150: 100%|██████████| 800/800 [00:04<00:00, 195.02it/s]
# The loss for epoch 128 is 0.8059946269541979
# Epoch 129/150: 100%|██████████| 800/800 [00:04<00:00, 194.76it/s]
# The loss for epoch 129 is 0.8456556014046073
# Epoch 130/150: 100%|██████████| 800/800 [00:04<00:00, 194.18it/s]
# The loss for epoch 130 is 0.7771247230693697
# Epoch 131/150: 100%|██████████| 800/800 [00:04<00:00, 199.10it/s]
# The loss for epoch 131 is 0.8268754475899041
# 100%|██████████| 12/12 [00:05<00:00,  2.37it/s]
# Epoch 132/150: 100%|██████████| 800/800 [00:04<00:00, 194.96it/s]
# The loss for epoch 132 is 0.7713052886202931
# Epoch 133/150: 100%|██████████| 800/800 [00:04<00:00, 195.11it/s]
# The loss for epoch 133 is 0.8276471516117454
# Epoch 134/150: 100%|██████████| 800/800 [00:04<00:00, 183.72it/s]
# The loss for epoch 134 is 0.8214539593085647
# Epoch 135/150: 100%|██████████| 800/800 [00:04<00:00, 193.55it/s]
# The loss for epoch 135 is 0.7930890795737505
# Epoch 136/150: 100%|██████████| 800/800 [00:04<00:00, 194.63it/s]
# The loss for epoch 136 is 0.8256024437099695
# Epoch 137/150: 100%|██████████| 800/800 [00:04<00:00, 192.67it/s]
# The loss for epoch 137 is 0.8056490095183253
# Epoch 138/150: 100%|██████████| 800/800 [00:04<00:00, 190.44it/s]
# The loss for epoch 138 is 0.7784356216788292
# Epoch 139/150: 100%|██████████| 800/800 [00:04<00:00, 194.43it/s]
# The loss for epoch 139 is 0.7863343232646585
# Epoch 140/150: 100%|██████████| 800/800 [00:04<00:00, 192.92it/s]
# The loss for epoch 140 is 0.7437006987333298
# Epoch 141/150: 100%|██████████| 800/800 [00:04<00:00, 195.91it/s]
# The loss for epoch 141 is 0.8100706590339541
# 100%|██████████| 12/12 [00:05<00:00,  2.33it/s]
# Epoch 142/150: 100%|██████████| 800/800 [00:03<00:00, 201.10it/s]
# The loss for epoch 142 is 0.7590505715310574
# Epoch 143/150: 100%|██████████| 800/800 [00:04<00:00, 193.94it/s]
# The loss for epoch 143 is 0.7658774511963129
# Epoch 144/150: 100%|██████████| 800/800 [00:04<00:00, 194.84it/s]
# The loss for epoch 144 is 0.7989510519802571
# Epoch 145/150: 100%|██████████| 800/800 [00:04<00:00, 193.80it/s]
# The loss for epoch 145 is 0.7682257264666259
# Epoch 146/150: 100%|██████████| 800/800 [00:04<00:00, 199.73it/s]
# The loss for epoch 146 is 0.8041809062287212
# Epoch 147/150: 100%|██████████| 800/800 [00:04<00:00, 180.23it/s]
# The loss for epoch 147 is 0.8173647550567985
# Epoch 148/150: 100%|██████████| 800/800 [00:04<00:00, 178.96it/s]
# The loss for epoch 148 is 0.7911089622117579
# Epoch 149/150: 100%|██████████| 800/800 [00:04<00:00, 186.95it/s]
# The loss for epoch 149 is 0.787685788616538
# Epoch 150/150: 100%|██████████| 800/800 [00:04<00:00, 195.18it/s]
# The loss for epoch 150 is 0.7617089334763587
# 100%|██████████| 12/12 [00:05<00:00,  2.27it/s]
# Training Report :
# +--------------------------+-------------------------------+
# | Key                      | Value                         |
# +==========================+===============================+
# | num_epoch                | 150                           |
# +--------------------------+-------------------------------+
# | batch_size               | 250                           |
# +--------------------------+-------------------------------+
# | gradient_clip_threshhold | 1                             |
# +--------------------------+-------------------------------+
# | eval_frequency           | 10                            |
# +--------------------------+-------------------------------+
# | sample_size              | 3000                          |
# +--------------------------+-------------------------------+
# | data_name                | [('moons', ''), ('dino', '')] |
# +--------------------------+-------------------------------+
# | device                   | cuda                          |
# +--------------------------+-------------------------------+
# | best loss achieved       | 0.7437006987333298            |
# +--------------------------+-------------------------------+

# %%
import torch
import os 

path_to_best_model = tinyDiff_builder.trainer.checkpoints_dir_path.split('Project_tiny_diffusion/')[-1]
path_to_best_model_attention = os.path.join(path_to_best_model , 'attention_best_loss.pth')
path_to_best_model_model = os.path.join(path_to_best_model , 'model_best_loss.pth')
tinyDiff_builder.model.load_state_dict(torch.load(path_to_best_model_model))
tinyDiff_builder.attention.load_state_dict(torch.load(path_to_best_model_attention))
# Out:
# <All keys matched successfully>

# %%
pah = tinyDiff_builder.trainer.model_save_path.split("Project_tiny_diffusion/")[-1]
print(pah)
# Out:
# Outputs/Residual_with_old_attention_date_2024-03-15_12_810154

# %%
import os 
import numpy as np
framse_np = np.load(os.path.join(pah, 'framse.npy'))

# %%
import matplotlib.pyplot as plt



fig, axs = plt.subplots(5, 2, figsize=(15, 15))

for i, ax in enumerate(axs.flat):
    ax.scatter(framse_np[i, :, 0], framse_np[i, :, 1], s=2)
    ax.set_title(f"Scatter Plot of the {i * 10} epoch")

plt.tight_layout()
plt.show()

# %%
# sampleing : 

fig, axs = plt.subplots(5, 2, figsize=(15, 15))
for i, ax in enumerate(axs.flat):
    sample = tinyDiff_builder.trainer.sample(3000 ) 
    
    sample_np = np.concatenate(sample , axis=0)

    ax.scatter(sample_np[:, 0], sample_np[:, 1] , s = 3)
    ax.set_title(f"Scatter Plot of a sampled example")
plt.tight_layout()
plt.show()
# Out:
# 100%|██████████| 12/12 [00:04<00:00,  2.47it/s]
# 100%|██████████| 12/12 [00:04<00:00,  2.47it/s]
# 100%|██████████| 12/12 [00:04<00:00,  2.47it/s]
# 100%|██████████| 12/12 [00:04<00:00,  2.47it/s]
# 100%|██████████| 12/12 [00:04<00:00,  2.47it/s]
# 100%|██████████| 12/12 [00:04<00:00,  2.47it/s]
# 100%|██████████| 12/12 [00:04<00:00,  2.47it/s]
# 100%|██████████| 12/12 [00:04<00:00,  2.48it/s]
# 100%|██████████| 12/12 [00:04<00:00,  2.47it/s]
# 100%|██████████| 12/12 [00:04<00:00,  2.48it/s]
