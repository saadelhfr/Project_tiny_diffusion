# %%
from src.layers.Models import TinyDiffusion 

from torch.utils.data import DataLoader
from src.data.BaseData import DataSetTinyDiffusion
from src.utils.manage_device import select_device
# Out:
# /Data/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
cfg = {'device': 'cuda', 
       'model_type': 
                {'model_name': 'Residual_with_attention'}, 
     'model': {'Model': {'depth': 5, 'size': 256, 'hidden_dim':1200, 'output_dim': 2, 'pos_emb': 'sinusoidal', 'input_size': 2}, 'attention': {'input_dim': 512, 'output_dim': 2, 'max_length': 100, 'size': 256}}, 
     'trainer': {'num_epoch':150, 'batch_size': 100, 'gradient_clip_threshhold': 1, 'eval_frequency': 10, 'sample_size': 1000, 'scale_train': 1, 'periodic_resets': 0, 'len_independant_data': 400}, 
     'dataset': {'number_data_points': 5000, 'joined': 1, 'name_dataset': [['dino', ''], ['mnist', 'density_map_0.pt']]}, 
     'optimizer': {'lr': 0.001, 'weight_decay':0}, 
     'Diffusion': {'num_timesteps':250, 'beta_start': 0.0001, 'beta_end': 0.02, 'beta_schedule': 'quadratic'}}

# %%
model_name = cfg["model_type"]["model_name"]
device = select_device(cfg['device'])
    # Correct way to merge dictionaries and add a new key in Python
model_config = {**cfg["model"], "device": device}
dataset_config = {**cfg["dataset"], "device": device}
dataset_config["name_dataset"] = [("dino", ""), ("moons", ""), ("dino", ""), ("moons", ""), ("dino", ""), ("moons", "")  ]
trainer_config = {
    **cfg["trainer"],
    "data_name": dataset_config["name_dataset"],
    "device": device,
}
optimizer_config = {**cfg["optimizer"]}
diff_config = {**cfg["Diffusion"], "device": device}

# %%
tinyDiff_builder = TinyDiffusion(
    model_name, model_config, trainer_config, optimizer_config, diff_config, device
)
print(tinyDiff_builder)
dataset = DataSetTinyDiffusion(**dataset_config)
print(dataset)
train_loader = DataLoader(
    dataset, batch_size=int(trainer_config["batch_size"]), shuffle=False
)
print(train_loader)
tinyDiff_builder.train(train_loader)
# Out:
# <src.layers.Models.TinyDiffusion object at 0x7fa13dc747d0>
# [<src.data.CombinedData.CombinedDataset object at 0x7fa0fd078c50>, <src.data.CombinedData.CombinedDataset object at 0x7fa0fd0e2ad0>, <src.data.CombinedData.CombinedDataset object at 0x7fa0fd9c6190>, <src.data.CombinedData.CombinedDataset object at 0x7fa0fde43bd0>, <src.data.CombinedData.CombinedDataset object at 0x7fa0fd8b62d0>, <src.data.CombinedData.CombinedDataset object at 0x7fa0fc34f2d0>]
# <src.data.BaseData.DataSetTinyDiffusion object at 0x7fa13dc77610>
# <torch.utils.data.dataloader.DataLoader object at 0x7fa0fc437890>
# Epoch 1/150: 100%|██████████| 60/60 [00:00<00:00, 97.23it/s]
# The loss for epoch 1 is 1.0006721287965774
# 100%|██████████| 10/10 [00:07<00:00,  1.41it/s]
# Epoch 2/150: 100%|██████████| 60/60 [00:00<00:00, 116.71it/s]
# The loss for epoch 2 is 0.5617567121982574
# Epoch 3/150: 100%|██████████| 60/60 [00:00<00:00, 118.51it/s]
# The loss for epoch 3 is 0.5168950670957565
# Epoch 4/150: 100%|██████████| 60/60 [00:00<00:00, 130.98it/s]
# The loss for epoch 4 is 0.5244649079442024
# Epoch 5/150: 100%|██████████| 60/60 [00:00<00:00, 120.14it/s]
# The loss for epoch 5 is 0.5070623451471329
# Epoch 6/150: 100%|██████████| 60/60 [00:00<00:00, 116.63it/s]
# The loss for epoch 6 is 0.4988384860754013
# Epoch 7/150: 100%|██████████| 60/60 [00:00<00:00, 117.43it/s]
# The loss for epoch 7 is 0.4981136083602905
# Epoch 8/150: 100%|██████████| 60/60 [00:00<00:00, 124.46it/s]
# The loss for epoch 8 is 0.46610343128442766
# Epoch 9/150: 100%|██████████| 60/60 [00:00<00:00, 130.62it/s]
# The loss for epoch 9 is 0.49623613119125365
# Epoch 10/150: 100%|██████████| 60/60 [00:00<00:00, 124.92it/s]
# The loss for epoch 10 is 0.45314967513084414
# Epoch 11/150: 100%|██████████| 60/60 [00:00<00:00, 132.17it/s]
# The loss for epoch 11 is 0.47349823206663133
# 100%|██████████| 10/10 [00:07<00:00,  1.40it/s]
# Epoch 12/150: 100%|██████████| 60/60 [00:00<00:00, 133.96it/s]
# The loss for epoch 12 is 0.4597644373774529
# Epoch 13/150: 100%|██████████| 60/60 [00:00<00:00, 122.45it/s]
# The loss for epoch 13 is 0.45203796863555906
# Epoch 14/150: 100%|██████████| 60/60 [00:00<00:00, 133.00it/s]
# The loss for epoch 14 is 0.46358822494745255
# Epoch 15/150: 100%|██████████| 60/60 [00:00<00:00, 135.40it/s]
# The loss for epoch 15 is 0.47555940061807633
# Epoch 16/150: 100%|██████████| 60/60 [00:00<00:00, 134.32it/s]
# The loss for epoch 16 is 0.4604443073272705
# Epoch 17/150: 100%|██████████| 60/60 [00:00<00:00, 134.15it/s]
# The loss for epoch 17 is 0.4689749372005463
# Epoch 18/150: 100%|██████████| 60/60 [00:00<00:00, 123.93it/s]
# The loss for epoch 18 is 0.44712687104940413
# Epoch 19/150: 100%|██████████| 60/60 [00:00<00:00, 133.76it/s]
# The loss for epoch 19 is 0.49681529015302656
# Epoch 20/150: 100%|██████████| 60/60 [00:00<00:00, 134.46it/s]
# The loss for epoch 20 is 0.44776476949453353
# Epoch 21/150: 100%|██████████| 60/60 [00:00<00:00, 134.32it/s]
# The loss for epoch 21 is 0.46600070476531985
# 100%|██████████| 10/10 [00:07<00:00,  1.41it/s]
# Epoch 22/150: 100%|██████████| 60/60 [00:00<00:00, 134.44it/s]
# The loss for epoch 22 is 0.4732692301273346
# Epoch 23/150: 100%|██████████| 60/60 [00:00<00:00, 119.44it/s]
# The loss for epoch 23 is 0.44437881261110307
# Epoch 24/150: 100%|██████████| 60/60 [00:00<00:00, 114.76it/s]
# The loss for epoch 24 is 0.42825109481811524
# Epoch 25/150: 100%|██████████| 60/60 [00:00<00:00, 126.30it/s]
# The loss for epoch 25 is 0.45221511453390123
# Epoch 26/150: 100%|██████████| 60/60 [00:00<00:00, 131.00it/s]
# The loss for epoch 26 is 0.43234378188848493
# Epoch 27/150: 100%|██████████| 60/60 [00:00<00:00, 131.38it/s]
# The loss for epoch 27 is 0.4529238837957382
# Epoch 28/150: 100%|██████████| 60/60 [00:00<00:00, 133.76it/s]
# The loss for epoch 28 is 0.4358795818686485
# Epoch 29/150: 100%|██████████| 60/60 [00:00<00:00, 134.34it/s]
# The loss for epoch 29 is 0.43081835061311724
# Epoch 30/150: 100%|██████████| 60/60 [00:00<00:00, 135.27it/s]
# The loss for epoch 30 is 0.4485016846656799
# Epoch 31/150: 100%|██████████| 60/60 [00:00<00:00, 135.10it/s]
# The loss for epoch 31 is 0.4475307196378708
# 100%|██████████| 10/10 [00:07<00:00,  1.40it/s]
# Epoch 32/150: 100%|██████████| 60/60 [00:00<00:00, 134.58it/s]
# The loss for epoch 32 is 0.44059170961380006
# Epoch 33/150: 100%|██████████| 60/60 [00:00<00:00, 134.40it/s]
# The loss for epoch 33 is 0.4565331843495369
# Epoch 34/150: 100%|██████████| 60/60 [00:00<00:00, 134.85it/s]
# The loss for epoch 34 is 0.4528790208697319
# Epoch 35/150: 100%|██████████| 60/60 [00:00<00:00, 134.99it/s]
# The loss for epoch 35 is 0.44619555354118345
# Epoch 36/150: 100%|██████████| 60/60 [00:00<00:00, 134.79it/s]
# The loss for epoch 36 is 0.4512834694981575
# Epoch 37/150: 100%|██████████| 60/60 [00:00<00:00, 134.44it/s]
# The loss for epoch 37 is 0.4334357139468193
# Epoch 38/150: 100%|██████████| 60/60 [00:00<00:00, 135.09it/s]
# The loss for epoch 38 is 0.44044997870922087
# Epoch 39/150: 100%|██████████| 60/60 [00:00<00:00, 135.24it/s]
# The loss for epoch 39 is 0.4483654499053955
# Epoch 40/150: 100%|██████████| 60/60 [00:00<00:00, 134.49it/s]
# The loss for epoch 40 is 0.4377672788500786
# Epoch 41/150: 100%|██████████| 60/60 [00:00<00:00, 134.52it/s]
# The loss for epoch 41 is 0.45368589252233504
# 100%|██████████| 10/10 [00:07<00:00,  1.40it/s]
# Epoch 42/150: 100%|██████████| 60/60 [00:00<00:00, 133.16it/s]
# The loss for epoch 42 is 0.4421801692247391
# Epoch 43/150: 100%|██████████| 60/60 [00:00<00:00, 134.50it/s]
# The loss for epoch 43 is 0.4331198814511299
# Epoch 44/150: 100%|██████████| 60/60 [00:00<00:00, 134.13it/s]
# The loss for epoch 44 is 0.4381972977519035
# Epoch 45/150: 100%|██████████| 60/60 [00:00<00:00, 134.43it/s]
# The loss for epoch 45 is 0.4388322514295578
# Epoch 46/150: 100%|██████████| 60/60 [00:00<00:00, 134.23it/s]
# The loss for epoch 46 is 0.4442584493756294
# Epoch 47/150: 100%|██████████| 60/60 [00:00<00:00, 122.32it/s]
# The loss for epoch 47 is 0.4181626877188683
# Epoch 48/150: 100%|██████████| 60/60 [00:00<00:00, 126.84it/s]
# The loss for epoch 48 is 0.4393445110321045
# Epoch 49/150: 100%|██████████| 60/60 [00:00<00:00, 129.85it/s]
# The loss for epoch 49 is 0.42196401923894883
# Epoch 50/150: 100%|██████████| 60/60 [00:00<00:00, 129.97it/s]
# The loss for epoch 50 is 0.43979801893234255
# Epoch 51/150: 100%|██████████| 60/60 [00:00<00:00, 129.97it/s]
# The loss for epoch 51 is 0.44674269527196886
# 100%|██████████| 10/10 [00:07<00:00,  1.32it/s]
# Epoch 52/150: 100%|██████████| 60/60 [00:00<00:00, 129.36it/s]
# The loss for epoch 52 is 0.465185681283474
# Epoch 53/150: 100%|██████████| 60/60 [00:00<00:00, 130.06it/s]
# The loss for epoch 53 is 0.45302886962890626
# Epoch 54/150: 100%|██████████| 60/60 [00:00<00:00, 130.12it/s]
# The loss for epoch 54 is 0.4533050116896629
# Epoch 55/150: 100%|██████████| 60/60 [00:00<00:00, 115.35it/s]
# The loss for epoch 55 is 0.4141359716653824
# Epoch 56/150: 100%|██████████| 60/60 [00:00<00:00, 127.38it/s]
# The loss for epoch 56 is 0.4453417801856995
# Epoch 57/150: 100%|██████████| 60/60 [00:00<00:00, 129.80it/s]
# The loss for epoch 57 is 0.4375572788715363
# Epoch 58/150: 100%|██████████| 60/60 [00:00<00:00, 127.19it/s]
# The loss for epoch 58 is 0.4628601175546646
# Epoch 59/150: 100%|██████████| 60/60 [00:00<00:00, 129.88it/s]
# The loss for epoch 59 is 0.4283491000533104
# Epoch 60/150: 100%|██████████| 60/60 [00:00<00:00, 129.95it/s]
# The loss for epoch 60 is 0.44124540776014326
# Epoch 61/150: 100%|██████████| 60/60 [00:00<00:00, 127.56it/s]
# The loss for epoch 61 is 0.4255945837497711
# 100%|██████████| 10/10 [00:07<00:00,  1.32it/s]
# Epoch 62/150: 100%|██████████| 60/60 [00:00<00:00, 129.41it/s]
# The loss for epoch 62 is 0.44777920305728913
# Epoch 63/150: 100%|██████████| 60/60 [00:00<00:00, 129.96it/s]
# The loss for epoch 63 is 0.42627509742975234
# Epoch 64/150: 100%|██████████| 60/60 [00:00<00:00, 129.81it/s]
# The loss for epoch 64 is 0.4316837540268898
# Epoch 65/150: 100%|██████████| 60/60 [00:00<00:00, 130.09it/s]
# The loss for epoch 65 is 0.4327572891116142
# Epoch 66/150: 100%|██████████| 60/60 [00:00<00:00, 129.06it/s]
# The loss for epoch 66 is 0.4345099192857742
# Epoch 67/150: 100%|██████████| 60/60 [00:00<00:00, 130.13it/s]
# The loss for epoch 67 is 0.4233110424876213
# Epoch 68/150: 100%|██████████| 60/60 [00:00<00:00, 127.64it/s]
# The loss for epoch 68 is 0.4419142773747444
# Epoch 69/150: 100%|██████████| 60/60 [00:00<00:00, 125.64it/s]
# The loss for epoch 69 is 0.41933987885713575
# Epoch 70/150: 100%|██████████| 60/60 [00:00<00:00, 128.09it/s]
# The loss for epoch 70 is 0.44204952239990236
# Epoch 71/150: 100%|██████████| 60/60 [00:00<00:00, 128.56it/s]
# The loss for epoch 71 is 0.4145560222864151
# 100%|██████████| 10/10 [00:07<00:00,  1.33it/s]
# Epoch 72/150: 100%|██████████| 60/60 [00:00<00:00, 127.45it/s]
# The loss for epoch 72 is 0.43965438067913054
# Epoch 73/150: 100%|██████████| 60/60 [00:00<00:00, 128.45it/s]
# The loss for epoch 73 is 0.4315496522188187
# Epoch 74/150: 100%|██████████| 60/60 [00:00<00:00, 113.72it/s]
# The loss for epoch 74 is 0.40868683606386186
# Epoch 75/150: 100%|██████████| 60/60 [00:00<00:00, 124.30it/s]
# The loss for epoch 75 is 0.43553044080734254
# Epoch 76/150: 100%|██████████| 60/60 [00:00<00:00, 125.07it/s]
# The loss for epoch 76 is 0.4197896242141724
# Epoch 77/150: 100%|██████████| 60/60 [00:00<00:00, 127.18it/s]
# The loss for epoch 77 is 0.44778490751981737
# Epoch 78/150: 100%|██████████| 60/60 [00:00<00:00, 128.25it/s]
# The loss for epoch 78 is 0.44241496235132216
# Epoch 79/150: 100%|██████████| 60/60 [00:00<00:00, 128.50it/s]
# The loss for epoch 79 is 0.4534239855408668
# Epoch 80/150: 100%|██████████| 60/60 [00:00<00:00, 127.85it/s]
# The loss for epoch 80 is 0.4411310687661171
# Epoch 81/150: 100%|██████████| 60/60 [00:00<00:00, 128.39it/s]
# The loss for epoch 81 is 0.42868926376104355
# 100%|██████████| 10/10 [00:07<00:00,  1.32it/s]
# Epoch 82/150: 100%|██████████| 60/60 [00:00<00:00, 126.23it/s]
# The loss for epoch 82 is 0.425196176469326
# Epoch 83/150: 100%|██████████| 60/60 [00:00<00:00, 112.04it/s]
# The loss for epoch 83 is 0.40550253927707675
# Epoch 84/150: 100%|██████████| 60/60 [00:00<00:00, 128.92it/s]
# The loss for epoch 84 is 0.4154969614744186
# Epoch 85/150: 100%|██████████| 60/60 [00:00<00:00, 129.74it/s]
# The loss for epoch 85 is 0.4449918070435524
# Epoch 86/150: 100%|██████████| 60/60 [00:00<00:00, 129.88it/s]
# The loss for epoch 86 is 0.44699647605419157
# Epoch 87/150: 100%|██████████| 60/60 [00:00<00:00, 129.81it/s]
# The loss for epoch 87 is 0.43132914453744886
# Epoch 88/150: 100%|██████████| 60/60 [00:00<00:00, 129.97it/s]
# The loss for epoch 88 is 0.41646569162607194
# Epoch 89/150: 100%|██████████| 60/60 [00:00<00:00, 129.14it/s]
# The loss for epoch 89 is 0.4427422738075256
# Epoch 90/150: 100%|██████████| 60/60 [00:00<00:00, 129.62it/s]
# The loss for epoch 90 is 0.4456629002094269
# Epoch 91/150: 100%|██████████| 60/60 [00:00<00:00, 129.85it/s]
# The loss for epoch 91 is 0.43389204174280166
# 100%|██████████| 10/10 [00:07<00:00,  1.32it/s]
# Epoch 92/150: 100%|██████████| 60/60 [00:00<00:00, 129.07it/s]
# The loss for epoch 92 is 0.42552148520946503
# Epoch 93/150: 100%|██████████| 60/60 [00:00<00:00, 130.04it/s]
# The loss for epoch 93 is 0.4431651484966278
# Epoch 94/150: 100%|██████████| 60/60 [00:00<00:00, 128.91it/s]
# The loss for epoch 94 is 0.43918577283620835
# Epoch 95/150: 100%|██████████| 60/60 [00:00<00:00, 129.61it/s]
# The loss for epoch 95 is 0.4168860962986946
# Epoch 96/150: 100%|██████████| 60/60 [00:00<00:00, 129.69it/s]
# The loss for epoch 96 is 0.43637447744607927
# Epoch 97/150: 100%|██████████| 60/60 [00:00<00:00, 129.71it/s]
# The loss for epoch 97 is 0.4085847228765488
# Epoch 98/150: 100%|██████████| 60/60 [00:00<00:00, 129.77it/s]
# The loss for epoch 98 is 0.4291523662209511
# Epoch 99/150: 100%|██████████| 60/60 [00:00<00:00, 129.26it/s]
# The loss for epoch 99 is 0.4401333248615265
# Epoch 100/150: 100%|██████████| 60/60 [00:00<00:00, 129.51it/s]
# The loss for epoch 100 is 0.42014877051115035
# Epoch 101/150: 100%|██████████| 60/60 [00:00<00:00, 129.49it/s]
# The loss for epoch 101 is 0.4203276088833809
# 100%|██████████| 10/10 [00:07<00:00,  1.33it/s]
# Epoch 102/150: 100%|██████████| 60/60 [00:00<00:00, 128.64it/s]
# The loss for epoch 102 is 0.436146399974823
# Epoch 103/150: 100%|██████████| 60/60 [00:00<00:00, 113.30it/s]
# The loss for epoch 103 is 0.40400143176317216
# Epoch 104/150: 100%|██████████| 60/60 [00:00<00:00, 125.38it/s]
# The loss for epoch 104 is 0.422703954577446
# Epoch 105/150: 100%|██████████| 60/60 [00:00<00:00, 129.50it/s]
# The loss for epoch 105 is 0.41846800297498704
# Epoch 106/150: 100%|██████████| 60/60 [00:00<00:00, 128.21it/s]
# The loss for epoch 106 is 0.42484377533197404
# Epoch 107/150: 100%|██████████| 60/60 [00:00<00:00, 128.50it/s]
# The loss for epoch 107 is 0.4389198824763298
# Epoch 108/150: 100%|██████████| 60/60 [00:00<00:00, 128.93it/s]
# The loss for epoch 108 is 0.4272304531931877
# Epoch 109/150: 100%|██████████| 60/60 [00:00<00:00, 129.85it/s]
# The loss for epoch 109 is 0.4341100236773491
# Epoch 110/150: 100%|██████████| 60/60 [00:00<00:00, 129.41it/s]
# The loss for epoch 110 is 0.4291669091582298
# Epoch 111/150: 100%|██████████| 60/60 [00:00<00:00, 129.62it/s]
# The loss for epoch 111 is 0.40579636603593827
# 100%|██████████| 10/10 [00:07<00:00,  1.32it/s]
# Epoch 112/150: 100%|██████████| 60/60 [00:00<00:00, 128.98it/s]
# The loss for epoch 112 is 0.4139335346221924
# Epoch 113/150: 100%|██████████| 60/60 [00:00<00:00, 129.80it/s]
# The loss for epoch 113 is 0.4068708100914955
# Epoch 114/150: 100%|██████████| 60/60 [00:00<00:00, 130.05it/s]
# The loss for epoch 114 is 0.4339188927412033
# Epoch 115/150: 100%|██████████| 60/60 [00:00<00:00, 129.69it/s]
# The loss for epoch 115 is 0.42613377392292023
# Epoch 116/150: 100%|██████████| 60/60 [00:00<00:00, 129.85it/s]
# The loss for epoch 116 is 0.4215305894613266
# Epoch 117/150: 100%|██████████| 60/60 [00:00<00:00, 129.33it/s]
# The loss for epoch 117 is 0.41551324039697646
# Epoch 118/150: 100%|██████████| 60/60 [00:00<00:00, 128.81it/s]
# The loss for epoch 118 is 0.4224123096466064
# Epoch 119/150: 100%|██████████| 60/60 [00:00<00:00, 117.04it/s]
# The loss for epoch 119 is 0.3994688794016838
# Epoch 120/150: 100%|██████████| 60/60 [00:00<00:00, 121.95it/s]
# The loss for epoch 120 is 0.43712377339601516
# Epoch 121/150: 100%|██████████| 60/60 [00:00<00:00, 128.96it/s]
# The loss for epoch 121 is 0.43319595605134964
# 100%|██████████| 10/10 [00:07<00:00,  1.32it/s]
# Epoch 122/150: 100%|██████████| 60/60 [00:00<00:00, 127.09it/s]
# The loss for epoch 122 is 0.42100526064634325
# Epoch 123/150: 100%|██████████| 60/60 [00:00<00:00, 128.35it/s]
# The loss for epoch 123 is 0.4397680166363716
# Epoch 124/150: 100%|██████████| 60/60 [00:00<00:00, 114.26it/s]
# The loss for epoch 124 is 0.39587498366832735
# Epoch 125/150: 100%|██████████| 60/60 [00:00<00:00, 126.33it/s]
# The loss for epoch 125 is 0.4294320049881935
# Epoch 126/150: 100%|██████████| 60/60 [00:00<00:00, 128.84it/s]
# The loss for epoch 126 is 0.4204989695549011
# Epoch 127/150: 100%|██████████| 60/60 [00:00<00:00, 128.42it/s]
# The loss for epoch 127 is 0.41537240833044053
# Epoch 128/150: 100%|██████████| 60/60 [00:00<00:00, 128.71it/s]
# The loss for epoch 128 is 0.44057265371084214
# Epoch 129/150: 100%|██████████| 60/60 [00:00<00:00, 128.55it/s]
# The loss for epoch 129 is 0.41698891431093216
# Epoch 130/150: 100%|██████████| 60/60 [00:00<00:00, 128.52it/s]
# The loss for epoch 130 is 0.4139818960428238
# Epoch 131/150: 100%|██████████| 60/60 [00:00<00:00, 128.31it/s]
# The loss for epoch 131 is 0.4150989204645157
# 100%|██████████| 10/10 [00:07<00:00,  1.32it/s]
# Epoch 132/150: 100%|██████████| 60/60 [00:00<00:00, 127.60it/s]
# The loss for epoch 132 is 0.4087031269073486
# Epoch 133/150: 100%|██████████| 60/60 [00:00<00:00, 128.66it/s]
# The loss for epoch 133 is 0.4120576384663582
# Epoch 134/150: 100%|██████████| 60/60 [00:00<00:00, 128.48it/s]
# The loss for epoch 134 is 0.41789875358343126
# Epoch 135/150: 100%|██████████| 60/60 [00:00<00:00, 128.82it/s]
# The loss for epoch 135 is 0.41553955048322677
# Epoch 136/150: 100%|██████████| 60/60 [00:00<00:00, 128.11it/s]
# The loss for epoch 136 is 0.4156443700194359
# Epoch 137/150: 100%|██████████| 60/60 [00:00<00:00, 128.39it/s]
# The loss for epoch 137 is 0.4268238961696625
# Epoch 138/150: 100%|██████████| 60/60 [00:00<00:00, 128.15it/s]
# The loss for epoch 138 is 0.40496635109186174
# Epoch 139/150: 100%|██████████| 60/60 [00:00<00:00, 128.43it/s]
# The loss for epoch 139 is 0.41660983592271805
# Epoch 140/150: 100%|██████████| 60/60 [00:00<00:00, 128.34it/s]
# The loss for epoch 140 is 0.42793567329645155
# Epoch 141/150: 100%|██████████| 60/60 [00:00<00:00, 122.95it/s]
# The loss for epoch 141 is 0.4126205506920815
# 100%|██████████| 10/10 [00:07<00:00,  1.32it/s]
# Epoch 142/150: 100%|██████████| 60/60 [00:00<00:00, 127.49it/s]
# The loss for epoch 142 is 0.40593079894781114
# Epoch 143/150: 100%|██████████| 60/60 [00:00<00:00, 128.43it/s]
# The loss for epoch 143 is 0.4086877548694611
# Epoch 144/150: 100%|██████████| 60/60 [00:00<00:00, 128.41it/s]
# The loss for epoch 144 is 0.41265219420194627
# Epoch 145/150: 100%|██████████| 60/60 [00:00<00:00, 128.73it/s]
# The loss for epoch 145 is 0.41118948101997377
# Epoch 146/150: 100%|██████████| 60/60 [00:00<00:00, 128.28it/s]
# The loss for epoch 146 is 0.4332992640137672
# Epoch 147/150: 100%|██████████| 60/60 [00:00<00:00, 128.75it/s]
# The loss for epoch 147 is 0.40151384472846985
# Epoch 148/150: 100%|██████████| 60/60 [00:00<00:00, 123.91it/s]
# The loss for epoch 148 is 0.42510070085525514
# Epoch 149/150: 100%|██████████| 60/60 [00:00<00:00, 124.27it/s]
# The loss for epoch 149 is 0.4161646822094917
# Epoch 150/150: 100%|██████████| 60/60 [00:00<00:00, 128.11it/s]
# The loss for epoch 150 is 0.40834594815969466
# 100%|██████████| 10/10 [00:07<00:00,  1.32it/s]
# Training Report :
# +--------------------------+-----------------------------------------------------------------------------------------+
# | Key                      | Value                                                                                   |
# +==========================+=========================================================================================+
# | num_epoch                | 150                                                                                     |
# +--------------------------+-----------------------------------------------------------------------------------------+
# | batch_size               | 100                                                                                     |
# +--------------------------+-----------------------------------------------------------------------------------------+
# | gradient_clip_threshhold | 1                                                                                       |
# +--------------------------+-----------------------------------------------------------------------------------------+
# | eval_frequency           | 10                                                                                      |
# +--------------------------+-----------------------------------------------------------------------------------------+
# | sample_size              | 1000                                                                                    |
# +--------------------------+-----------------------------------------------------------------------------------------+
# | scale_train              | 1                                                                                       |
# +--------------------------+-----------------------------------------------------------------------------------------+
# | periodic_resets          | 0                                                                                       |
# +--------------------------+-----------------------------------------------------------------------------------------+
# | len_independant_data     | 400                                                                                     |
# +--------------------------+-----------------------------------------------------------------------------------------+
# | data_name                | [('dino', ''), ('moons', ''), ('dino', ''), ('moons', ''), ('dino', ''), ('moons', '')] |
# +--------------------------+-----------------------------------------------------------------------------------------+
# | device                   | cuda                                                                                    |
# +--------------------------+-----------------------------------------------------------------------------------------+
# | best loss achieved       | 0.39587498366832735                                                                     |
# +--------------------------+-----------------------------------------------------------------------------------------+

# %%
import torch
import os 

path_to_best_model = tinyDiff_builder.trainer.checkpoints_dir_path.split('Project_tiny_diffusion/')[-1]
path_to_best_model_attention = os.path.join(path_to_best_model , 'attention_best_loss.pth')
path_to_best_model_model = os.path.join(path_to_best_model , 'model_best_loss.pth')
tinyDiff_builder.model.load_state_dict(torch.load(path_to_best_model_model))
tinyDiff_builder.attention.load_state_dict(torch.load(path_to_best_model_attention))
# Out:
# <All keys matched successfully>

# %%
pah = tinyDiff_builder.trainer.model_save_path
print(pah)
# Out:
# /Data/saadelhfr/MAP583/Project_tiny_diffusion/Outputs/Residual_with_attention_date_2024-03-14_23_0d8ffb

# %%
import os 
import numpy as np
framse_path = os.path.join(pah, "frames")
framse_np = np.load(
"Outputs/Residual_with_attention_date_2024-03-14_23_0d8ffb/framse.npy"
)

# %%
import matplotlib.pyplot as plt


framse_np_1 = framse_np[0]
framse_np_2 = framse_np[-1]

fig, axs = plt.subplots(5, 3, figsize=(15, 15))

for i, ax in enumerate(axs.flat):
    ax.scatter(framse_np[i, :, 0], framse_np[i, :, 1], s=2)
    ax.set_title(f"Scatter Plot {i * 10}")

plt.tight_layout()
plt.show()

# %%
# sampleing : 

for _ in range(10): 
    sample = tinyDiff_builder.trainer.sample(1000) 
    
    sample_np = np.concatenate(sample , axis=0)

    plt.scatter(sample_np[:, 0], sample_np[:, 1] , s = 3)
    plt.show()
# Out:
# 100%|██████████| 10/10 [00:07<00:00,  1.32it/s]
# 100%|██████████| 10/10 [00:07<00:00,  1.32it/s]
# 100%|██████████| 10/10 [00:07<00:00,  1.34it/s]
# 100%|██████████| 10/10 [00:07<00:00,  1.38it/s]
# 100%|██████████| 10/10 [00:07<00:00,  1.38it/s]
# 100%|██████████| 10/10 [00:07<00:00,  1.37it/s]
# 100%|██████████| 10/10 [00:07<00:00,  1.37it/s]
#  50%|█████     | 5/10 [00:03<00:03,  1.37it/s]
