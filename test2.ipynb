# %%
from src.layers.Models import TinyDiffusion 

from torch.utils.data import DataLoader
from src.data.BaseData import DataSetTinyDiffusion
from src.utils.manage_device import select_device
# Out:
# /Data/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
cfg = {'device': 'cuda', 
       'model_type': 
                {'model_name': 'Residual_with_attention'}, 
     'model': {'Model': {'depth': 5, 'size': 256, 'hidden_dim':1200, 'output_dim': 2, 'pos_emb': 'sinusoidal', 'input_size': 2}, 'attention': {'input_dim': 512, 'output_dim': 2, 'max_length': 100, 'size': 256}}, 
     'trainer': {'num_epoch':50, 'batch_size': 100, 'gradient_clip_threshhold': 1, 'eval_frequency': 10, 'sample_size': 1000, 'scale_train': 1, 'periodic_resets': 0, 'len_independant_data': 400}, 
     'dataset': {'number_data_points': 10000, 'joined': 1, 'name_dataset': [['dino', ''], ['mnist', 'density_map_0.pt']]}, 
     'optimizer': {'lr': 0.001, 'weight_decay':0}, 
     'Diffusion': {'num_timesteps':250, 'beta_start': 0.0001, 'beta_end': 0.02, 'beta_schedule': 'quadratic'}}

# %%
model_name = cfg["model_type"]["model_name"]
device = select_device(cfg['device'])
    # Correct way to merge dictionaries and add a new key in Python
model_config = {**cfg["model"], "device": device}
dataset_config = {**cfg["dataset"], "device": device}
dataset_config["name_dataset"] = [("dino", ""), ("moons", "")]
trainer_config = {
    **cfg["trainer"],
    "data_name": dataset_config["name_dataset"],
    "device": device,
}
optimizer_config = {**cfg["optimizer"]}
diff_config = {**cfg["Diffusion"], "device": device}

# %%
tinyDiff_builder = TinyDiffusion(
    model_name, model_config, trainer_config, optimizer_config, diff_config, device
)
print(tinyDiff_builder)
dataset = DataSetTinyDiffusion(**dataset_config)
print(dataset)
train_loader = DataLoader(
    dataset, batch_size=int(trainer_config["batch_size"]), shuffle=False
)
print(train_loader)
tinyDiff_builder.train(train_loader)
# Out:
# <src.layers.Models.TinyDiffusion object at 0x7fca25d398d0>
# [<src.data.CombinedData.CombinedDataset object at 0x7fc9e56a5550>, <src.data.CombinedData.CombinedDataset object at 0x7fc9e5dfea50>, <src.data.CombinedData.CombinedDataset object at 0x7fc9e58e3650>, <src.data.CombinedData.CombinedDataset object at 0x7fc9e459e1d0>, <src.data.CombinedData.CombinedDataset object at 0x7fc9e459f2d0>, <src.data.CombinedData.CombinedDataset object at 0x7fc9e459e650>]
# <src.data.BaseData.DataSetTinyDiffusion object at 0x7fc9e5628090>
# <torch.utils.data.dataloader.DataLoader object at 0x7fc9e57a0190>
# Epoch 1/150: 100%|██████████| 300/300 [00:01<00:00, 180.19it/s]
# The loss for epoch 1 is 2.9492876237630843
# 100%|██████████| 10/10 [00:07<00:00,  1.32it/s]
# Epoch 2/150: 100%|██████████| 300/300 [00:01<00:00, 192.87it/s]
# The loss for epoch 2 is 2.4012619042396546
# Epoch 3/150: 100%|██████████| 300/300 [00:01<00:00, 194.11it/s]
# The loss for epoch 3 is 2.280716345012188
# Epoch 4/150: 100%|██████████| 300/300 [00:01<00:00, 199.70it/s]
# The loss for epoch 4 is 2.292569600045681
# Epoch 5/150: 100%|██████████| 300/300 [00:01<00:00, 199.08it/s]
# The loss for epoch 5 is 2.322244658470154
# Epoch 6/150: 100%|██████████| 300/300 [00:01<00:00, 193.42it/s]
# The loss for epoch 6 is 2.276178822517395
# Epoch 7/150: 100%|██████████| 300/300 [00:01<00:00, 192.00it/s]
# The loss for epoch 7 is 2.2005412319302557
# Epoch 8/150: 100%|██████████| 300/300 [00:01<00:00, 200.31it/s]
# The loss for epoch 8 is 2.223951646089554
# Epoch 9/150: 100%|██████████| 300/300 [00:01<00:00, 202.58it/s]
# The loss for epoch 9 is 2.253196030855179
# Epoch 10/150: 100%|██████████| 300/300 [00:01<00:00, 201.70it/s]
# The loss for epoch 10 is 2.244593648016453
# Epoch 11/150: 100%|██████████| 300/300 [00:01<00:00, 202.09it/s]
# The loss for epoch 11 is 2.247540336549282
# 100%|██████████| 10/10 [00:07<00:00,  1.32it/s]
# Epoch 12/150: 100%|██████████| 300/300 [00:01<00:00, 201.54it/s]
# The loss for epoch 12 is 2.246018011868
# Epoch 13/150: 100%|██████████| 300/300 [00:01<00:00, 202.10it/s]
# The loss for epoch 13 is 2.2203906321525575
# Epoch 14/150: 100%|██████████| 300/300 [00:01<00:00, 202.31it/s]
# The loss for epoch 14 is 2.230170931518078
# Epoch 15/150: 100%|██████████| 300/300 [00:01<00:00, 202.28it/s]
# The loss for epoch 15 is 2.5600509881973266
# Epoch 16/150: 100%|██████████| 300/300 [00:01<00:00, 201.74it/s]
# The loss for epoch 16 is 2.2313382479548456
# Epoch 17/150: 100%|██████████| 300/300 [00:01<00:00, 197.07it/s]
# The loss for epoch 17 is 2.2071223118901253
# Epoch 18/150: 100%|██████████| 300/300 [00:01<00:00, 194.12it/s]
# The loss for epoch 18 is 2.1708899769186973
# Epoch 19/150: 100%|██████████| 300/300 [00:01<00:00, 198.24it/s]
# The loss for epoch 19 is 2.2010771787166594
# Epoch 20/150: 100%|██████████| 300/300 [00:01<00:00, 199.09it/s]
# The loss for epoch 20 is 2.171007217168808
# Epoch 21/150: 100%|██████████| 300/300 [00:01<00:00, 200.28it/s]
# The loss for epoch 21 is 2.1834878394007684
# 100%|██████████| 10/10 [00:07<00:00,  1.32it/s]
# Epoch 22/150: 100%|██████████| 300/300 [00:01<00:00, 198.54it/s]
# The loss for epoch 22 is 5.289208114147186
# Epoch 23/150: 100%|██████████| 300/300 [00:01<00:00, 198.31it/s]
# The loss for epoch 23 is 2.2283717519044877
# Epoch 24/150: 100%|██████████| 300/300 [00:01<00:00, 200.62it/s]
# The loss for epoch 24 is 2.2073419696092604
# Epoch 25/150: 100%|██████████| 300/300 [00:01<00:00, 191.51it/s]
# The loss for epoch 25 is 2.156644225418568
# Epoch 26/150: 100%|██████████| 300/300 [00:01<00:00, 200.26it/s]
# The loss for epoch 26 is 40.925354107916355
# Epoch 27/150: 100%|██████████| 300/300 [00:01<00:00, 203.13it/s]
# The loss for epoch 27 is 2.187652096450329
# Epoch 28/150: 100%|██████████| 300/300 [00:01<00:00, 204.05it/s]
# The loss for epoch 28 is 2.234934579432011
# Epoch 29/150: 100%|██████████| 300/300 [00:01<00:00, 202.88it/s]
# The loss for epoch 29 is 2.225424208343029
# Epoch 30/150: 100%|██████████| 300/300 [00:01<00:00, 202.61it/s]
# The loss for epoch 30 is 2.1772467079758644
# Epoch 31/150: 100%|██████████| 300/300 [00:01<00:00, 201.98it/s]
# The loss for epoch 31 is 2.198338297903538
# 100%|██████████| 10/10 [00:07<00:00,  1.38it/s]
# Epoch
# 100%|██████████| 10/10 [00:07<00:00,  1.37it/s]
# Epoch 122/150: 100%|██████████| 300/300 [00:01<00:00, 204.35it/s]
# The loss for epoch 122 is 5.568756388127804
# Epoch 123/150: 100%|██████████| 300/300 [00:01<00:00, 199.07it/s]
# The loss for epoch 123 is 2.1230518928170206
# Epoch 124/150: 100%|██████████| 300/300 [00:01<00:00, 202.64it/s]
# The loss for epoch 124 is 2.1138170185685157
# Epoch 125/150: 100%|██████████| 300/300 [00:01<00:00, 201.98it/s]
# The loss for epoch 125 is 2.1129872205853464
# Epoch 126/150: 100%|██████████| 300/300 [00:01<00:00, 201.54it/s]
# The loss for epoch 126 is 2.067981504201889
# Epoch 127/150: 100%|██████████| 300/300 [00:01<00:00, 202.56it/s]
# The loss for epoch 127 is 2.1977105340361596
# Epoch 128/150: 100%|██████████| 300/300 [00:01<00:00, 202.57it/s]
# The loss for epoch 128 is 2.1205551502108575
# Epoch 129/150: 100%|██████████| 300/300 [00:01<00:00, 202.61it/s]
# The loss for epoch 129 is 2.080739249587059
# Epoch 130/150: 100%|██████████| 300/300 [00:01<00:00, 199.38it/s]
# The loss for epoch 130 is 2.097611759006977
# Epoch 131/150: 100%|██████████| 300/300 [00:01<00:00, 195.43it/s]
# The loss for epoch 131 is 2.062296288907528
# 100%|██████████| 10/10 [00:07<00:00,  1.31it/s]
# Epoch 132/150: 100%|██████████| 300/300 [00:01<00:00, 196.74it/s]
# The loss for epoch 132 is 2.0813603165745733
# Epoch 133/150: 100%|██████████| 300/300 [00:01<00:00, 198.59it/s]
# The loss for epoch 133 is 2.1170247748494146
# Epoch 134/150: 100%|██████████| 300/300 [00:01<00:00, 198.88it/s]
# The loss for epoch 134 is 2.093384562730789
# Epoch 135/150: 100%|██████████| 300/300 [00:01<00:00, 199.64it/s]
# The loss for epoch 135 is 2.146668713092804
# Epoch 136/150: 100%|██████████| 300/300 [00:01<00:00, 198.61it/s]
# The loss for epoch 136 is 2.0902538201212884
# Epoch 137/150: 100%|██████████| 300/300 [00:01<00:00, 199.02it/s]
# The loss for epoch 137 is 2.10450865149498
# Epoch 138/150: 100%|██████████| 300/300 [00:01<00:00, 199.03it/s]
# The loss for epoch 138 is 2.1474374437332155
# Epoch 139/150: 100%|██████████| 300/300 [00:01<00:00, 197.74it/s]
# The loss for epoch 139 is 2.0805056086182594
# Epoch 140/150: 100%|██████████| 300/300 [00:01<00:00, 199.63it/s]
# The loss for epoch 140 is 2.1323740202188493
# Epoch 141/150: 100%|██████████| 300/300 [00:01<00:00, 200.96it/s]
# The loss for epoch 141 is 2.0811858516931534
# 100%|██████████| 10/10 [00:07<00:00,  1.31it/s]
# Epoch 142/150: 100%|██████████| 300/300 [00:01<00:00, 200.01it/s]
# The loss for epoch 142 is 2.1180430254340172
# Epoch 143/150: 100%|██████████| 300/300 [00:01<00:00, 201.22it/s]
# The loss for epoch 143 is 2.08680195659399
# Epoch 144/150: 100%|██████████| 300/300 [00:01<00:00, 200.79it/s]
# The loss for epoch 144 is 2.125828372836113
# Epoch 145/150: 100%|██████████| 300/300 [00:01<00:00, 200.94it/s]
# The loss for epoch 145 is 2.0841021913290025
# Epoch 146/150: 100%|██████████| 300/300 [00:01<00:00, 201.63it/s]
# The loss for epoch 146 is 38.78712521493435
# Epoch 147/150: 100%|██████████| 300/300 [00:01<00:00, 200.72it/s]
# The loss for epoch 147 is 2.071927646398544
# Epoch 148/150: 100%|██████████| 300/300 [00:01<00:00, 200.26it/s]
# The loss for epoch 148 is 2.0844970163702965
# Epoch 149/150: 100%|██████████| 300/300 [00:01<00:00, 196.06it/s]
# The loss for epoch 149 is 2.1019863095879554
# Epoch 150/150: 100%|██████████| 300/300 [00:01<00:00, 201.10it/s]
# The loss for epoch 150 is 2.0732289749383925
# 100%|██████████| 10/10 [00:07<00:00,  1.32it/s]
# Training Report :
# +--------------------------+-----------------------------------------------------------------------------------------+
# | Key                      | Value                                                                                   |
# +==========================+=========================================================================================+
# | num_epoch                | 150                                                                                     |
# +--------------------------+-----------------------------------------------------------------------------------------+
# | batch_size               | 100                                                                                     |
# +--------------------------+-----------------------------------------------------------------------------------------+
# | gradient_clip_threshhold | 1                                                                                       |
# +--------------------------+-----------------------------------------------------------------------------------------+
# | eval_frequency           | 10                                                                                      |
# +--------------------------+-----------------------------------------------------------------------------------------+
# | sample_size              | 1000                                                                                    |
# +--------------------------+-----------------------------------------------------------------------------------------+
# | scale_train              | 1                                                                                       |
# +--------------------------+-----------------------------------------------------------------------------------------+
# | periodic_resets          | 0                                                                                       |
# +--------------------------+-----------------------------------------------------------------------------------------+
# | len_independant_data     | 400                                                                                     |
# +--------------------------+-----------------------------------------------------------------------------------------+
# | data_name                | [('dino', ''), ('moons', ''), ('dino', ''), ('moons', ''), ('dino', ''), ('moons', '')] |
# +--------------------------+-----------------------------------------------------------------------------------------+
# | device                   | cuda                                                                                    |
# +--------------------------+-----------------------------------------------------------------------------------------+
# | best loss achieved       | 2.062296288907528                                                                       |
# +--------------------------+-----------------------------------------------------------------------------------------+

# %%
import torch
import os 

path_to_best_model = tinyDiff_builder.trainer.checkpoints_dir_path.split('Project_tiny_diffusion/')[-1]
path_to_best_model_attention = os.path.join(path_to_best_model , 'attention_best_loss.pth')
path_to_best_model_model = os.path.join(path_to_best_model , 'model_best_loss.pth')
tinyDiff_builder.model.load_state_dict(torch.load(path_to_best_model_model))
tinyDiff_builder.attention.load_state_dict(torch.load(path_to_best_model_attention))
# Out:
# <All keys matched successfully>

# %%
pah = tinyDiff_builder.trainer.model_save_path
print(pah)
# Out:
# /Data/saadelhfr/MAP583/Project_tiny_diffusion/Outputs/Residual_with_attention_date_2024-03-15_00_000a70

# %%
import os 
import numpy as np
framse_path = os.path.join(pah, "frames")
framse_np = np.load(
"Outputs/Residual_with_attention_date_2024-03-15_00_000a70/framse.npy"
)

# %%
import matplotlib.pyplot as plt


framse_np_1 = framse_np[0]
framse_np_2 = framse_np[-1]

fig, axs = plt.subplots(5, 3, figsize=(15, 15))

for i, ax in enumerate(axs.flat):
    ax.scatter(framse_np[i, :, 0], framse_np[i, :, 1], s=2)
    ax.set_title(f"Scatter Plot {i * 10}")

plt.tight_layout()
plt.show()

# %%
# sampleing : 

for _ in range(10): 
    sample = tinyDiff_builder.trainer.sample(1000) 
    
    sample_np = np.concatenate(sample , axis=0)

    plt.scatter(sample_np[:, 0], sample_np[:, 1] , s = 3)
    plt.show()
# Out:
# 100%|██████████| 10/10 [00:07<00:00,  1.32it/s]
# 100%|██████████| 10/10 [00:07<00:00,  1.33it/s]
# 100%|██████████| 10/10 [00:07<00:00,  1.33it/s]
# 100%|██████████| 10/10 [00:07<00:00,  1.33it/s]
# 100%|██████████| 10/10 [00:07<00:00,  1.33it/s]
# 100%|██████████| 10/10 [00:07<00:00,  1.32it/s]
# 100%|██████████| 10/10 [00:07<00:00,  1.31it/s]
# 100%|██████████| 10/10 [00:07<00:00,  1.32it/s]
# 100%|██████████| 10/10 [00:07<00:00,  1.33it/s]
# 100%|██████████| 10/10 [00:07<00:00,  1.33it/s]

# %%
# plot the attention weight : 

import matplotlib.pyplot as plt

attention = tinyDiff_builder.attention

fig, axs = plt.subplots(5, 3, figsize=(15, 15))

for i, ax in enumerate(axs.flat):

    ax.imshow(attention[i].detach().cpu().numpy())
    ax.set_title(f"Attention weight {i * 10}")

plt.tight_layout()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 11
#       7 fig, axs = plt.subplots(5, 3, figsize=(15, 15))
#       9 for i, ax in enumerate(axs.flat):
# ---> 11     ax.imshow(attention[i].detach().cpu().numpy())
#      12     ax.set_title(f"Attention weight {i * 10}")
#      14 plt.tight_layout()
#
# TypeError: 'RollingAttention2' object is not subscriptable
